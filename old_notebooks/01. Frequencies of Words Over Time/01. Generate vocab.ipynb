# %%
print("hello world")
# Out:
# hello world

# %%
import os
data_path = "/home/ec2-user/SageMaker/data/refugee_dataset_v1/"
assert os.path.exists(data_path)

files = os.listdir(data_path)
len(files)
# Out:
# 205538

# %%
from lxml import etree
from bs4 import BeautifulSoup
import spacy

nlp = spacy.load('en_core_web_sm', disable=['tagger', 'parser', 'ner','textcat','lemmatizer'])

# We define a function to get the text content that we need from the XML articles available in our dataset
def getxmlcontent(root):
    if root.find('.//HiddenText') is not None:
        return(root.find('.//HiddenText').text)
    
    elif root.find('.//Text') is not None:
        return(root.find('.//Text').text)
    
    else:
        return None

# %%
from collections import defaultdict
total_count = defaultdict(int)
count_per_article = defaultdict(int)
for file in files[:50]:
    tree = etree.parse(data_path + file)
    root = tree.getroot()
    
    if getxmlcontent(root) is not None:
        soup = BeautifulSoup(getxmlcontent(root),parser='html.parser', features="lxml")
        text = soup.get_text()
        tokens = [token.text for token in nlp(text) if not token.is_stop and token.is_alpha]
        for token in tokens:
            total_count[token]+=1
        for token in set(tokens):
            count_per_article[token]+=1

assert len(count_per_article)==len(total_count)
# print(f'Vocab size after removing terms that appear less than i articles')

print(' i,    appears more than i times, appears more than in i articles.')
for i in range(41):
    print(f'{i:2}:   '\
          f'{len([word for word in total_count if total_count[word]>i]):8}, '\
          f'{len([word for word in count_per_article if count_per_article[word]>i]):8}')
    
print(f'Removing terms that only appear one time in the corpus '\
      f'(-{len([word for word in total_count if total_count[word]==1])})')
for word in set(total_count):
    if total_count[word]==1:
            del(total_count[word])
            del(count_per_article[word])
print(f'vocab size: {len(total_count)}')
assert len(count_per_article)==len(total_count)

vocab = {}
for word in total_count:
    vocab[word] = {}
    vocab[word]['total_count'] = total_count[word]
    vocab[word]['article_count'] = count_per_article[word]

import pickle
vocab_file = '/home/ec2-user/SageMaker/mariano/notebooks/01. Frequencies of Words Over Time/data/vocab.p'
pickle.dump(vocab, open(vocab_file, 'wb'))
# Out:
#  i,    appears more than i times, appears more than in i articles.
#  0:      21245,    21245
#  1:       6633,     5463
#  2:       3904,     2928
#  3:       2729,     1889
#  4:       2002,     1338
#  5:       1585,      980
#  6:       1302,      756
#  7:       1076,      590
#  8:        917,      458
#  9:        789,      365
# 10:        685,      306
# 11:        608,      261
# 12:        536,      215
# 13:        478,      174
# 14:        425,      141
# 15:        380,      114
# 16:        345,       89
# 17:        317,       73
# 18:        291,       62
# 19:        278,       49
# 20:        260,       40
# 21:        237,       32
# 22:        222,       27
# 23:        208,       22
# 24:        192,       19
# 25:        175,       15
# 26:        160,       14
# 27:        154,       12
# 28:        144,        9
# 29:        134,        7
# 30:        124,        5
# 31:        115,        5
# 32:        107,        5
# 33:        101,        2
# 34:         95,        1
# 35:         90,        1
# 36:         89,        1
# 37:         83,        1
# 38:         77,        1
# 39:         72,        1
# 40:         67,        0
# Removing terms that only appear one time in the corpus (-14612)
# vocab size: 6633

# %%
a = defaultdict(int)
a['hola']=2
a['hello']=1
a
# Out:
# defaultdict(int, {'hola': 2, 'hello': 1})

# %%
pickle.load(open(vocab_file, 'rb'))
# Out:
# {'Sport': {'total_count': 4, 'article_count': 2},
#  'Sports': {'total_count': 2, 'article_count': 2},
#  'Editor': {'total_count': 5, 'article_count': 2},
#  'ot': {'total_count': 28, 'article_count': 14},
#  'Globe': {'total_count': 10, 'article_count': 8},
#  'Leafs': {'total_count': 13, 'article_count': 4},
#  'Beat': {'total_count': 4, 'article_count': 2},
#  'hits': {'total_count': 5, 'article_count': 3},
#  'Leaf': {'total_count': 7, 'article_count': 3},
#  'yesterday': {'total_count': 68, 'article_count': 21},
#  'defeated': {'total_count': 7, 'article_count': 5},
#  'place': {'total_count': 39, 'article_count': 21},
#  'half': {'total_count': 18, 'article_count': 14},
#  'game': {'total_count': 32, 'article_count': 9},
#  'league': {'total_count': 18, 'article_count': 4},
#  'leading': {'total_count': 6, 'article_count': 5},
#  'Royals': {'total_count': 4, 'article_count': 2},
#  'Orioles': {'total_count': 3, 'article_count': 1},
#  'Frank': {'total_count': 9, 'article_count': 7},
#  'went': {'total_count': 21, 'article_count': 17},
#  'route': {'total_count': 7, 'article_count': 7},
#  'won': {'total_count': 40, 'article_count': 9},
#  'second': {'total_count': 29, 'article_count': 16},
#  'start': {'total_count': 22, 'article_count': 15},
#  'evident': {'total_count': 3, 'article_count': 3},
#  'big': {'total_count': 28, 'article_count': 17},
#  'headed': {'total_count': 4, 'article_count': 4},
#  'successful': {'total_count': 3, 'article_count': 3},
#  'season': {'total_count': 28, 'article_count': 8},
#  'Little': {'total_count': 7, 'article_count': 5},
#  'Harry': {'total_count': 4, 'article_count': 3},
#  'Davis': {'total_count': 10, 'article_count': 7},
#  'stole': {'total_count': 4, 'article_count': 3},
#  'connected': {'total_count': 5, 'article_count': 4},
#  'safeties': {'total_count': 2, 'article_count': 1},
#  'homer': {'total_count': 2, 'article_count': 1},
#  'days': {'total_count': 40, 'article_count': 22},
#  'hard': {'total_count': 12, 'article_count': 9},
#  'fight': {'total_count': 25, 'article_count': 13},
#  'year': {'total_count': 97, 'article_count': 29},
#  'Jimmy': {'total_count': 6, 'article_count': 6},
#  'available': {'total_count': 22, 'article_count': 15},
#  'base': {'total_count': 12, 'article_count': 7},
#  'duty': {'total_count': 4, 'article_count': 4},
#  'continues': {'total_count': 7, 'article_count': 7},
#  'ball': {'total_count': 9, 'article_count': 5},
#  'troubles': {'total_count': 2, 'article_count': 2},
#  'stands': {'total_count': 6, 'article_count': 6},
#  'Mickey': {'total_count': 2, 'article_count': 2},
#  'Baltimore': {'total_count': 12, 'article_count': 3},
#  'Rochester': {'total_count': 3, 'article_count': 2},
#  'staged': {'total_count': 4, 'article_count': 3},
#  'inning': {'total_count': 5, 'article_count': 3},
#  'finally': {'total_count': 9, 'article_count': 9},
#  'victory': {'total_count': 8, 'article_count': 6},
#  'close': {'total_count': 13, 'article_count': 10},
#  'Southerners': {'total_count': 3, 'article_count': 2},
#  's': {'total_count': 180, 'article_count': 40},
#  'home': {'total_count': 35, 'article_count': 23},
#  'run': {'total_count': 28, 'article_count': 14},
#  'ninth': {'total_count': 4, 'article_count': 2},
#  'enabling': {'total_count': 2, 'article_count': 2},
#  'tie': {'total_count': 4, 'article_count': 3},
#  'score': {'total_count': 10, 'article_count': 5},
#  'defeat': {'total_count': 5, 'article_count': 3},
#  'hi': {'total_count': 16, 'article_count': 12},
#  'kept': {'total_count': 11, 'article_count': 9},
#  'pace': {'total_count': 3, 'article_count': 2},
#  'Birds': {'total_count': 2, 'article_count': 2},
#  'Skeeters': {'total_count': 2, 'article_count': 2},
#  'Montreal': {'total_count': 25, 'article_count': 9},
#  'West': {'total_count': 33, 'article_count': 15},
#  'circuit': {'total_count': 5, 'article_count': 2},
#  'homers': {'total_count': 4, 'article_count': 3},
#  'came': {'total_count': 33, 'article_count': 19},
#  'far': {'total_count': 35, 'article_count': 14},
#  'playing': {'total_count': 6, 'article_count': 5},
#  'long': {'total_count': 30, 'article_count': 20},
#  'distance': {'total_count': 7, 'article_count': 6},
#  'great': {'total_count': 26, 'article_count': 13},
#  'showing': {'total_count': 8, 'article_count': 6},
#  'road': {'total_count': 28, 'article_count': 13},
#  'leaders': {'total_count': 28, 'article_count': 13},
#  'rallied': {'total_count': 2, 'article_count': 2},
#  'eighth': {'total_count': 4, 'article_count': 3},
#  'Newark': {'total_count': 5, 'article_count': 2},
#  'frame': {'total_count': 3, 'article_count': 3},
#  'Manager': {'total_count': 5, 'article_count': 4},
#  'hurlers': {'total_count': 3, 'article_count': 2},
#  'Thomas': {'total_count': 9, 'article_count': 5},
#  'tile': {'total_count': 7, 'article_count': 5},
#  'credited': {'total_count': 2, 'article_count': 2},
#  'Wesley': {'total_count': 2, 'article_count': 1},
#  'Ferrell': {'total_count': 3, 'article_count': 1},
#  'Indian': {'total_count': 11, 'article_count': 7},
#  'Ace': {'total_count': 2, 'article_count': 2},
#  'Browns': {'total_count': 3, 'article_count': 1},
#  'entered': {'total_count': 5, 'article_count': 5},
#  'baseball': {'total_count': 11, 'article_count': 4},
#  'Hall': {'total_count': 24, 'article_count': 10},
#  'Fame': {'total_count': 3, 'article_count': 2},
#  'Cleveland': {'total_count': 7, 'article_count': 3},
#  'yester': {'total_count': 3, 'article_count': 2},
#  'day': {'total_count': 118, 'article_count': 27},
#  'turned': {'total_count': 14, 'article_count': 12},
#  'St': {'total_count': 67, 'article_count': 17},
#  'Louis': {'total_count': 18, 'article_count': 8},
#  'hit': {'total_count': 11, 'article_count': 7},
#  'slightly': {'total_count': 2, 'article_count': 2},
#  'wild': {'total_count': 6, 'article_count': 4},
#  'walked': {'total_count': 5, 'article_count': 3},
#  'reached': {'total_count': 13, 'article_count': 10},
#  'owing': {'total_count': 6, 'article_count': 4},
#  'errors': {'total_count': 3, 'article_count': 3},
#  'got': {'total_count': 14, 'article_count': 9},
#  'fourth': {'total_count': 6, 'article_count': 3},
#  'Indians': {'total_count': 6, 'article_count': 5},
#  'total': {'total_count': 13, 'article_count': 9},
#  'Washington': {'total_count': 10, 'article_count': 5},
#  'New': {'total_count': 44, 'article_count': 19},
#  'York': {'total_count': 37, 'article_count': 14},
#  'Yankees': {'total_count': 3, 'article_count': 2},
#  'Ruth': {'total_count': 2, 'article_count': 2},
#  'nearly': {'total_count': 12, 'article_count': 9},
#  'entire': {'total_count': 5, 'article_count': 5},
#  'team': {'total_count': 31, 'article_count': 9},
#  'McCarthy': {'total_count': 4, 'article_count': 3},
#  'men': {'total_count': 75, 'article_count': 28},
#  'travelled': {'total_count': 2, 'article_count': 2},
#  'rocky': {'total_count': 3, 'article_count': 2},
#  'slugger': {'total_count': 2, 'article_count': 2},
#  'laid': {'total_count': 4, 'article_count': 4},
#  'low': {'total_count': 16, 'article_count': 12},
#  'Boston': {'total_count': 12, 'article_count': 5},
#  'Al': {'total_count': 9, 'article_count': 6},
#  'old': {'total_count': 48, 'article_count': 25},
#  'time': {'total_count': 91, 'article_count': 33},
#  'form': {'total_count': 9, 'article_count': 9},
#  'Detroit': {'total_count': 21, 'article_count': 6},
#  'Tigers': {'total_count': 2, 'article_count': 2},
#  'Park': {'total_count': 25, 'article_count': 12},
#  'meantime': {'total_count': 3, 'article_count': 3},
#  'Athletics': {'total_count': 2, 'article_count': 2},
#  'Red': {'total_count': 6, 'article_count': 4},
#  'Sox': {'total_count': 4, 'article_count': 3},
#  'rain': {'total_count': 11, 'article_count': 6},
#  'sent': {'total_count': 25, 'article_count': 16},
#  'world': {'total_count': 51, 'article_count': 21},
#  'champions': {'total_count': 2, 'article_count': 2},
#  'division': {'total_count': 6, 'article_count': 5},
#  'rest': {'total_count': 11, 'article_count': 9},
#  'games': {'total_count': 23, 'article_count': 6},
#  'setting': {'total_count': 5, 'article_count': 5},
#  'played': {'total_count': 12, 'article_count': 7},
#  'National': {'total_count': 21, 'article_count': 10},
#  'Chicago': {'total_count': 18, 'article_count': 8},
#  'Cubs': {'total_count': 4, 'article_count': 2},
#  'Cincinnati': {'total_count': 4, 'article_count': 2},
#  'Reds': {'total_count': 3, 'article_count': 2},
#  'Cardinals': {'total_count': 2, 'article_count': 2},
#  'stopped': {'total_count': 7, 'article_count': 6},
#  'Pittsburg': {'total_count': 5, 'article_count': 2},
#  'winning': {'total_count': 7, 'article_count': 5},
#  'teams': {'total_count': 14, 'article_count': 6},
#  'remain': {'total_count': 8, 'article_count': 6},
#  'Dan': {'total_count': 6, 'article_count': 5},
#  'Howley': {'total_count': 2, 'article_count': 1},
#  'getting': {'total_count': 9, 'article_count': 6},
#  'bad': {'total_count': 9, 'article_count': 7},
#  'break': {'total_count': 5, 'article_count': 3},
#  'trying': {'total_count': 10, 'article_count': 9},
#  'class': {'total_count': 19, 'article_count': 9},
#  'owners': {'total_count': 5, 'article_count': 5},
#  'willing': {'total_count': 3, 'article_count': 3},
#  'buy': {'total_count': 9, 'article_count': 7},
#  'star': {'total_count': 14, 'article_count': 10},
#  'players': {'total_count': 13, 'article_count': 7},
#  'clubs': {'total_count': 4, 'article_count': 3},
#  'sell': {'total_count': 8, 'article_count': 6},
#  'result': {'total_count': 11, 'article_count': 8},
#  'likely': {'total_count': 13, 'article_count': 10},
#  'Oshawa': {'total_count': 9, 'article_count': 2},
#  'Play': {'total_count': 4, 'article_count': 3},
#  'Series': {'total_count': 4, 'article_count': 4},
#  'meeting': {'total_count': 30, 'article_count': 15},
#  'held': {'total_count': 31, 'article_count': 15},
#  'Lacrosse': {'total_count': 3, 'article_count': 2},
#  'Club': {'total_count': 21, 'article_count': 6},
#  'officials': {'total_count': 31, 'article_count': 15},
#  'Jy': {'total_count': 2, 'article_count': 2},
#  'decided': {'total_count': 13, 'article_count': 8},
#  'operate': {'total_count': 4, 'article_count': 4},
#  'senior': {'total_count': 5, 'article_count': 4},
#  'intermediate': {'total_count': 5, 'article_count': 3},
#  'series': {'total_count': 13, 'article_count': 6},
#  'means': {'total_count': 11, 'article_count': 8},
#  'starters': {'total_count': 5, 'article_count': 4},
#  'follows': {'total_count': 5, 'article_count': 5},
#  'Brampton': {'total_count': 4, 'article_count': 2},
#  'ton': {'total_count': 10, 'article_count': 7},
#  'Toronto': {'total_count': 101, 'article_count': 27},
#  'Simon': {'total_count': 8, 'article_count': 2},
#  'Native': {'total_count': 2, 'article_count': 1},
#  'Sons': {'total_count': 3, 'article_count': 2},
#  'reported': {'total_count': 21, 'article_count': 9},
#  'line': {'total_count': 18, 'article_count': 13},
#  'intended': {'total_count': 4, 'article_count': 4},
#  'high': {'total_count': 31, 'article_count': 15},
#  'Kelly': {'total_count': 4, 'article_count': 4},
#  'Bob': {'total_count': 8, 'article_count': 7},
#  'Stephenson': {'total_count': 3, 'article_count': 2},
#  'Alex': {'total_count': 2, 'article_count': 2},
#  'Shannon': {'total_count': 2, 'article_count': 2},
#  'Bill': {'total_count': 13, 'article_count': 9},
#  'Coulter': {'total_count': 2, 'article_count': 2},
#  'Chuck': {'total_count': 3, 'article_count': 2},
#  'Davidson': {'total_count': 2, 'article_count': 2},
#  'material': {'total_count': 5, 'article_count': 4},
#  'fill': {'total_count': 6, 'article_count': 6},
#  'gaps': {'total_count': 2, 'article_count': 2},
#  'Time': {'total_count': 17, 'article_count': 5},
#  'works': {'total_count': 6, 'article_count': 5},
#  'changes': {'total_count': 6, 'article_count': 6},
#  'lacrosse': {'total_count': 2, 'article_count': 1},
#  'sports': {'total_count': 2, 'article_count': 2},
#  'connection': {'total_count': 8, 'article_count': 7},
#  'interesting': {'total_count': 4, 'article_count': 4},
#  'recall': {'total_count': 3, 'article_count': 3},
#  'wen': {'total_count': 2, 'article_count': 2},
#  'Mann': {'total_count': 2, 'article_count': 2},
#  'Cup': {'total_count': 7, 'article_count': 3},
#  'Canadian': {'total_count': 54, 'article_count': 22},
#  'championship': {'total_count': 3, 'article_count': 2},
#  'years': {'total_count': 82, 'article_count': 30},
#  'ago': {'total_count': 29, 'article_count': 21},
#  'best': {'total_count': 28, 'article_count': 16},
#  'history': {'total_count': 15, 'article_count': 11},
#  'Lally': {'total_count': 2, 'article_count': 2},
#  'international': {'total_count': 10, 'article_count': 6},
#  'United': {'total_count': 47, 'article_count': 23},
#  'States': {'total_count': 39, 'article_count': 19},
#  'stars': {'total_count': 6, 'article_count': 5},
#  'believe': {'total_count': 11, 'article_count': 8},
#  'powerful': {'total_count': 3, 'article_count': 3},
#  'squad': {'total_count': 5, 'article_count': 3},
#  'enthusiastic': {'total_count': 5, 'article_count': 4},
#  'prospects': {'total_count': 2, 'article_count': 2},
#  'faced': {'total_count': 10, 'article_count': 9},
#  'process': {'total_count': 9, 'article_count': 8},
#  'Eddie': {'total_count': 6, 'article_count': 3},
#  'guided': {'total_count': 4, 'article_count': 2},
#  'return': {'total_count': 29, 'article_count': 16},
#  'cause': {'total_count': 22, 'article_count': 12},
#  'circles': {'total_count': 4, 'article_count': 3},
#  'add': {'total_count': 6, 'article_count': 5},
#  'interest': {'total_count': 29, 'article_count': 12},
#  'race': {'total_count': 29, 'article_count': 7},
#  'promises': {'total_count': 5, 'article_count': 4},
#  'Chesterfield': {'total_count': 4, 'article_count': 1},
#  'Fools': {'total_count': 2, 'article_count': 2},
#  'Critics': {'total_count': 2, 'article_count': 2},
#  'surprising': {'total_count': 2, 'article_count': 2},
#  'features': {'total_count': 7, 'article_count': 2},
#  'Old': {'total_count': 2, 'article_count': 2},
#  'Country': {'total_count': 8, 'article_count': 6},
#  'rise': {'total_count': 14, 'article_count': 5},
#  'months': {'total_count': 18, 'article_count': 13},
#  'fans': {'total_count': 4, 'article_count': 3},
#  'discussing': {'total_count': 5, 'article_count': 4},
#  'question': {'total_count': 30, 'article_count': 13},
#  'Lincoln': {'total_count': 3, 'article_count': 2},
#  'City': {'total_count': 16, 'article_count': 9},
#  'Tranmere': {'total_count': 2, 'article_count': 1},
#  'step': {'total_count': 8, 'article_count': 7},
#  'manner': {'total_count': 4, 'article_count': 4},
#  'expected': {'total_count': 15, 'article_count': 13},
#  'strain': {'total_count': 2, 'article_count': 2},
#  'Blue': {'total_count': 5, 'article_count': 4},
#  'passed': {'total_count': 8, 'article_count': 8},
#  'club': {'total_count': 21, 'article_count': 6},
#  'organized': {'total_count': 10, 'article_count': 7},
#  'ground': {'total_count': 8, 'article_count': 6},
#  'capable': {'total_count': 2, 'article_count': 2},
#  'holding': {'total_count': 5, 'article_count': 5},
#  'finished': {'total_count': 3, 'article_count': 3},
#  'standing': {'total_count': 6, 'article_count': 6},
#  'Steve': {'total_count': 6, 'article_count': 4},
#  'writing': {'total_count': 3, 'article_count': 3},
#  'Buffalo': {'total_count': 8, 'article_count': 4},
#  'Evening': {'total_count': 3, 'article_count': 3},
#  'News': {'total_count': 30, 'article_count': 8},
#  'pays': {'total_count': 3, 'article_count': 3},
#  'tribute': {'total_count': 4, 'article_count': 4},
#  'following': {'total_count': 10, 'article_count': 7},
#  'article': {'total_count': 4, 'article_count': 4},
#  'value': {'total_count': 9, 'article_count': 9},
#  'running': {'total_count': 5, 'article_count': 4},
#  'Look': {'total_count': 2, 'article_count': 2},
#  'runs': {'total_count': 12, 'article_count': 8},
#  'd': {'total_count': 49, 'article_count': 22},
#  'answer': {'total_count': 15, 'article_count': 8},
#  'Joe': {'total_count': 14, 'article_count': 9},
#  'demands': {'total_count': 6, 'article_count': 6},
#  'bases': {'total_count': 4, 'article_count': 4},
#  'pre': {'total_count': 9, 'article_count': 8},
#  'war': {'total_count': 58, 'article_count': 20},
#  'daring': {'total_count': 2, 'article_count': 2},
#  'chance': {'total_count': 9, 'article_count': 7},
#  'try': {'total_count': 16, 'article_count': 12},
#  'fellow': {'total_count': 11, 'article_count': 7},
#  'style': {'total_count': 6, 'article_count': 6},
#  'certainly': {'total_count': 6, 'article_count': 6},
#  'refreshing': {'total_count': 2, 'article_count': 2},
#  'note': {'total_count': 5, 'article_count': 5},
#  'kick': {'total_count': 2, 'article_count': 2},
#  'soaring': {'total_count': 2, 'article_count': 2},
#  'results': {'total_count': 4, 'article_count': 4},
#  'worth': {'total_count': 15, 'article_count': 9},
#  'insisting': {'total_count': 4, 'article_count': 4},
#  'system': {'total_count': 10, 'article_count': 7},
#  'paths': {'total_count': 2, 'article_count': 2},
#  'Heard': {'total_count': 2, 'article_count': 2},
#  'Charles': {'total_count': 9, 'article_count': 6},
#  'known': {'total_count': 16, 'article_count': 13},
#  'football': {'total_count': 7, 'article_count': 4},
#  'player': {'total_count': 10, 'article_count': 8},
#  'Private': {'total_count': 2, 'article_count': 2},
#  'Patients': {'total_count': 2, 'article_count': 2},
#  'General': {'total_count': 11, 'article_count': 9},
#  'Hospital': {'total_count': 9, 'article_count': 6},
#  'suffering': {'total_count': 3, 'article_count': 3},
#  'eye': {'total_count': 5, 'article_count': 4},
#  'having': {'total_count': 22, 'article_count': 13},
#  'received': {'total_count': 21, 'article_count': 13},
#  'bout': {'total_count': 3, 'article_count': 3},
#  'smoker': {'total_count': 2, 'article_count': 2},
#  'unfortunate': {'total_count': 3, 'article_count': 3},
#  'threatened': {'total_count': 3, 'article_count': 3},
#  'loss': {'total_count': 12, 'article_count': 7},
#  'sight': {'total_count': 3, 'article_count': 3},
#  'affected': {'total_count': 2, 'article_count': 2},
#  'con': {'total_count': 17, 'article_count': 12},
#  'dition': {'total_count': 2, 'article_count': 2},
#  'deeply': {'total_count': 5, 'article_count': 5},
#  'deplored': {'total_count': 3, 'article_count': 3},
#  'friends': {'total_count': 14, 'article_count': 10},
#  'Double': {'total_count': 4, 'article_count': 2},
#  'pals': {'total_count': 2, 'article_count': 2},
#  'officially': {'total_count': 2, 'article_count': 2},
#  'announced': {'total_count': 10, 'article_count': 7},
#  'George': {'total_count': 25, 'article_count': 15},
#  'Chairman': {'total_count': 3, 'article_count': 2},
#  'Racing': {'total_count': 2, 'article_count': 2},
#  'Associations': {'total_count': 3, 'article_count': 3},
#  'elected': {'total_count': 5, 'article_count': 4},
#  'successor': {'total_count': 2, 'article_count': 2},
#  'officers': {'total_count': 14, 'article_count': 9},
#  'Vice': {'total_count': 4, 'article_count': 4},
#  'Secretary': {'total_count': 16, 'article_count': 7},
#  'Treasurer': {'total_count': 4, 'article_count': 3},
#  'Miss': {'total_count': 11, 'article_count': 5},
#  'ranks': {'total_count': 3, 'article_count': 3},
#  'admitted': {'total_count': 8, 'article_count': 7},
#  'Hornsby': {'total_count': 3, 'article_count': 1},
#  'led': {'total_count': 17, 'article_count': 11},
#  'ting': {'total_count': 2, 'article_count': 2},
#  'story': {'total_count': 15, 'article_count': 12},
#  'goes': {'total_count': 10, 'article_count': 9},
#  'Wilson': {'total_count': 7, 'article_count': 4},
#  'king': {'total_count': 2, 'article_count': 2},
#  'majors': {'total_count': 2, 'article_count': 2},
#  'order': {'total_count': 19, 'article_count': 14},
#  'alleged': {'total_count': 6, 'article_count': 4},
#  'given': {'total_count': 26, 'article_count': 16},
#  'smaller': {'total_count': 2, 'article_count': 2},
#  'valuable': {'total_count': 4, 'article_count': 4},
#  'noted': {'total_count': 7, 'article_count': 5},
#  'silent': {'total_count': 3, 'article_count': 3},
#  'seven': {'total_count': 14, 'article_count': 11},
#  'thousand': {'total_count': 7, 'article_count': 7},
#  'people': {'total_count': 95, 'article_count': 34},
#  'attended': {'total_count': 4, 'article_count': 3},
#  'national': {'total_count': 19, 'article_count': 10},
#  'Hockey': {'total_count': 4, 'article_count': 3},
#  'League': {'total_count': 21, 'article_count': 4},
#  'play': {'total_count': 20, 'article_count': 11},
#  'Wind': {'total_count': 4, 'article_count': 4},
#  'sor': {'total_count': 2, 'article_count': 2},
#  'divide': {'total_count': 2, 'article_count': 2},
#  'addition': {'total_count': 2, 'article_count': 2},
#  'parade': {'total_count': 3, 'article_count': 2},
#  'receive': {'total_count': 7, 'article_count': 4},
#  'combined': {'total_count': 2, 'article_count': 2},
#  'sum': {'total_count': 7, 'article_count': 7},
#  'making': {'total_count': 12, 'article_count': 8},
#  'highest': {'total_count': 6, 'article_count': 5},
#  'winners': {'total_count': 3, 'article_count': 2},
#  'attendance': {'total_count': 2, 'article_count': 2},
#  'figures': {'total_count': 10, 'article_count': 8},
#  'Windsor': {'total_count': 6, 'article_count': 4},
#  'TORONTO': {'total_count': 33, 'article_count': 18},
#  'STAR': {'total_count': 25, 'article_count': 16},
#  'Saturday': {'total_count': 26, 'article_count': 11},
#  'February': {'total_count': 5, 'article_count': 3},
#  'b': {'total_count': 21, 'article_count': 12},
#  'Star': {'total_count': 32, 'article_count': 16},
#  'wholly': {'total_count': 2, 'article_count': 2},
#  'owned': {'total_count': 6, 'article_count': 4},
#  'BELAND': {'total_count': 3, 'article_count': 2},
#  'HONDERICH': {'total_count': 2, 'article_count': 1},
#  'Publisher': {'total_count': 2, 'article_count': 1},
#  'HARRY': {'total_count': 2, 'article_count': 2},
#  'HINDMARSH': {'total_count': 4, 'article_count': 2},
#  'Joseph': {'total_count': 8, 'article_count': 7},
#  'E': {'total_count': 18, 'article_count': 12},
#  'DAVID': {'total_count': 7, 'article_count': 4},
#  'JOLLEY': {'total_count': 2, 'article_count': 1},
#  'President': {'total_count': 25, 'article_count': 15},
#  'ATKINSON': {'total_count': 4, 'article_count': 2},
#  'January': {'total_count': 5, 'article_count': 4},
#  'circulation': {'total_count': 4, 'article_count': 3},
#  'Monday': {'total_count': 17, 'article_count': 10},
#  'Friday': {'total_count': 25, 'article_count': 13},
#  'BURNETT': {'total_count': 3, 'article_count': 3},
#  'THALL': {'total_count': 2, 'article_count': 2},
#  'MURRAY': {'total_count': 2, 'article_count': 2},
#  'Sunday': {'total_count': 21, 'article_count': 9},
#  'v': {'total_count': 71, 'article_count': 19},
#  'S': {'total_count': 107, 'article_count': 21},
#  'WILLIAM': {'total_count': 2, 'article_count': 2},
#  'CAMPBELL': {'total_count': 2, 'article_count': 2},
#  'PAUL': {'total_count': 4, 'article_count': 4},
#  'RUTH': {'total_count': 2, 'article_count': 2},
#  'T': {'total_count': 109, 'article_count': 17},
#  'peace': {'total_count': 23, 'article_count': 11},
#  'gas': {'total_count': 10, 'article_count': 6},
#  'm': {'total_count': 147, 'article_count': 25},
#  'Central': {'total_count': 13, 'article_count': 7},
#  'America': {'total_count': 20, 'article_count': 14},
#  'civil': {'total_count': 11, 'article_count': 8},
#  'hardly': {'total_count': 6, 'article_count': 5},
#  'way': {'total_count': 59, 'article_count': 28},
#  'bring': {'total_count': 8, 'article_count': 7},
#  'stability': {'total_count': 2, 'article_count': 2},
#  'V': {'total_count': 94, 'article_count': 19},
#  'J': {'total_count': 152, 'article_count': 18},
#  'upset': {'total_count': 2, 'article_count': 2},
#  'economic': {'total_count': 16, 'article_count': 5},
#  'progress': {'total_count': 5, 'article_count': 4},
#  'social': {'total_count': 24, 'article_count': 14},
#  'justice': {'total_count': 5, 'article_count': 4},
#  'j': {'total_count': 200, 'article_count': 20},
#  't': {'total_count': 177, 'article_count': 26},
#  'La': {'total_count': 10, 'article_count': 7},
#  'countries': {'total_count': 26, 'article_count': 9},
#  'peoples': {'total_count': 2, 'article_count': 2},
#  'lack': {'total_count': 9, 'article_count': 8},
#  'qualities': {'total_count': 2, 'article_count': 2},
#  'f': {'total_count': 167, 'article_count': 19},
#  'Oil': {'total_count': 10, 'article_count': 8},
#  'million': {'total_count': 38, 'article_count': 18},
#  'Venezuela': {'total_count': 4, 'article_count': 2},
#  'group': {'total_count': 28, 'article_count': 16},
#  'efforts': {'total_count': 5, 'article_count': 5},
#  'begun': {'total_count': 3, 'article_count': 3},
#  'fi': {'total_count': 15, 'article_count': 11},
#  'tb': {'total_count': 2, 'article_count': 2},
#  'granted': {'total_count': 5, 'article_count': 5},
#  'Haiti': {'total_count': 10, 'article_count': 3},
#  'dead': {'total_count': 14, 'article_count': 9},
#  'end': {'total_count': 37, 'article_count': 16},
#  'fall': {'total_count': 16, 'article_count': 13},
#  'revived': {'total_count': 5, 'article_count': 5},
#  'ih': {'total_count': 4, 'article_count': 4},
#  'W': {'total_count': 71, 'article_count': 16},
#  'lowing': {'total_count': 2, 'article_count': 2},
#  'mid': {'total_count': 7, 'article_count': 5},
#  'foreign': {'total_count': 26, 'article_count': 10},
#  'took': {'total_count': 30, 'article_count': 21},
#  'lv': {'total_count': 4, 'article_count': 4},
#  'Jean': {'total_count': 8, 'article_count': 6},
#  'Claude': {'total_count': 4, 'article_count': 4},
#  'Duvalier': {'total_count': 2, 'article_count': 1},
#  'renewed': {'total_count': 4, 'article_count': 3},
#  'diplomatic': {'total_count': 2, 'article_count': 2},
#  'activity': {'total_count': 3, 'article_count': 2},
#  'abandoned': {'total_count': 2, 'article_count': 2},
#  'dictatorship': {'total_count': 3, 'article_count': 2},
#  'Contadora': {'total_count': 2, 'article_count': 1},
#  'main': {'total_count': 11, 'article_count': 8},
#  'aim': {'total_count': 4, 'article_count': 4},
#  'agree': {'total_count': 2, 'article_count': 2},
#  'military': {'total_count': 31, 'article_count': 12},
#  'History': {'total_count': 5, 'article_count': 5},
#  'tells': {'total_count': 3, 'article_count': 3},
#  'Haitians': {'total_count': 2, 'article_count': 1},
#  'c': {'total_count': 41, 'article_count': 14},
#  'Hr': {'total_count': 2, 'article_count': 2},
#  'launched': {'total_count': 6, 'article_count': 6},
#  'bloody': {'total_count': 4, 'article_count': 4},
#  'slave': {'total_count': 9, 'article_count': 8},
#  'rebellions': {'total_count': 2, 'article_count': 2},
#  'rid': {'total_count': 3, 'article_count': 3},
#  'advisers': {'total_count': 2, 'article_count': 2},
#  'soil': {'total_count': 3, 'article_count': 3},
#  'reduce': {'total_count': 3, 'article_count': 2},
#  'control': {'total_count': 14, 'article_count': 9},
#  'arms': {'total_count': 14, 'article_count': 7},
#  'limit': {'total_count': 6, 'article_count': 6},
#  'troop': {'total_count': 2, 'article_count': 2},
#  'respect': {'total_count': 7, 'article_count': 5},
#  'bean': {'total_count': 2, 'article_count': 2},
#  'island': {'total_count': 15, 'article_count': 3},
#  'borders': {'total_count': 3, 'article_count': 3},
#  'agreement': {'total_count': 21, 'article_count': 11},
#  'tion': {'total_count': 49, 'article_count': 28},
#  'independence': {'total_count': 4, 'article_count': 3},
#  'France': {'total_count': 18, 'article_count': 8},
#  'Canada': {'total_count': 79, 'article_count': 24},
#  'experience': {'total_count': 5, 'article_count': 5},
#  'keeping': {'total_count': 3, 'article_count': 2},
#  'N': {'total_count': 18, 'article_count': 13},
#  'M': {'total_count': 136, 'article_count': 17},
#  'recognized': {'total_count': 3, 'article_count': 2},
#  'natural': {'total_count': 7, 'article_count': 6},
#  'verify': {'total_count': 2, 'article_count': 2},
#  'terms': {'total_count': 9, 'article_count': 8},
#  'followed': {'total_count': 10, 'article_count': 6},
#  'sides': {'total_count': 8, 'article_count': 4},
#  'help': {'total_count': 26, 'article_count': 17},
#  'secure': {'total_count': 5, 'article_count': 5},
#  'American': {'total_count': 40, 'article_count': 20},
#  'support': {'total_count': 15, 'article_count': 11},
#  'settlement': {'total_count': 6, 'article_count': 5},
#  'especially': {'total_count': 6, 'article_count': 4},
#  'r': {'total_count': 187, 'article_count': 21},
#  'generations': {'total_count': 3, 'article_count': 3},
#  'political': {'total_count': 13, 'article_count': 11},
#  'Affairs': {'total_count': 5, 'article_count': 5},
#  'Minister': {'total_count': 24, 'article_count': 16},
#  'Clark': {'total_count': 6, 'article_count': 3},
#  'backing': {'total_count': 3, 'article_count': 3},
#  'gg': {'total_count': 6, 'article_count': 4},
#  'si': {'total_count': 6, 'article_count': 5},
#  'n': {'total_count': 160, 'article_count': 23},
#  'Mt': {'total_count': 3, 'article_count': 2},
#  'ei': {'total_count': 4, 'article_count': 4},
#  'unrest': {'total_count': 4, 'article_count': 2},
#  'U': {'total_count': 84, 'article_count': 15},
#  'landed': {'total_count': 4, 'article_count': 4},
#  'careful': {'total_count': 2, 'article_count': 2},
#  'avoid': {'total_count': 3, 'article_count': 2},
#  'criticism': {'total_count': 9, 'article_count': 5},
#  'Reagan': {'total_count': 6, 'article_count': 3},
#  'approach': {'total_count': 3, 'article_count': 3},
#  'affairs': {'total_count': 10, 'article_count': 9},
#  'X': {'total_count': 30, 'article_count': 13},
#  'dreadful': {'total_count': 2, 'article_count': 2},
#  'regimes': {'total_count': 2, 'article_count': 2},
#  'casting': {'total_count': 2, 'article_count': 2},
#  'Cuba': {'total_count': 6, 'article_count': 5},
#  'tl': {'total_count': 7, 'article_count': 5},
#  'populace': {'total_count': 2, 'article_count': 2},
#  'shall': {'total_count': 2, 'article_count': 2},
#  'Communist': {'total_count': 6, 'article_count': 4},
#  'influence': {'total_count': 3, 'article_count': 2},
#  'southern': {'total_count': 6, 'article_count': 5},
#  'III': {'total_count': 15, 'article_count': 7},
#  'rl': {'total_count': 5, 'article_count': 5},
#  'threw': {'total_count': 2, 'article_count': 2},
#  'tyranny': {'total_count': 2, 'article_count': 2},
#  'considered': {'total_count': 12, 'article_count': 11},
#  'sponsored': {'total_count': 3, 'article_count': 3},
#  'pact': {'total_count': 2, 'article_count': 2},
#  'l': {'total_count': 81, 'article_count': 20},
#  'entitled': {'total_count': 5, 'article_count': 3},
#  'voice': {'total_count': 7, 'article_count': 5},
#  'pride': {'total_count': 5, 'article_count': 5},
#  'paper': {'total_count': 17, 'article_count': 9},
#  'written': {'total_count': 11, 'article_count': 9},
#  'impoverished': {'total_count': 2, 'article_count': 2},
#  'nation': {'total_count': 10, 'article_count': 9},
#  'said': {'total_count': 255, 'article_count': 33},
#  'recently': {'total_count': 7, 'article_count': 5},
#  'Ottawa': {'total_count': 24, 'article_count': 14},
#  'reception': {'total_count': 2, 'article_count': 2},
#  'read': {'total_count': 14, 'article_count': 8},
#  'ta': {'total_count': 4, 'article_count': 4},
#  'mg': {'total_count': 3, 'article_count': 2},
#  'Prime': {'total_count': 9, 'article_count': 8},
#  'Luis': {'total_count': 2, 'article_count': 2},
#  'Canadians': {'total_count': 20, 'article_count': 10},
#  'think': {'total_count': 32, 'article_count': 17},
#  'Medical': {'total_count': 5, 'article_count': 4},
#  'Association': {'total_count': 8, 'article_count': 6},
#  'K': {'total_count': 29, 'article_count': 12},
#  'CÂ': {'total_count': 2, 'article_count': 2},
#  'Independence': {'total_count': 2, 'article_count': 2},
#  'solved': {'total_count': 2, 'article_count': 2},
#  'region': {'total_count': 7, 'article_count': 6},
#  'debt': {'total_count': 25, 'article_count': 3},
#  'major': {'total_count': 10, 'article_count': 9},
#  'problem': {'total_count': 15, 'article_count': 10},
#  'self': {'total_count': 10, 'article_count': 9},
#  'described': {'total_count': 5, 'article_count': 4},
#  'L': {'total_count': 55, 'article_count': 17},
#  'Tt': {'total_count': 2, 'article_count': 2},
#  'ancestors': {'total_count': 2, 'article_count': 2},
#  'Americans': {'total_count': 9, 'article_count': 8},
#  'clear': {'total_count': 20, 'article_count': 15},
#  'large': {'total_count': 18, 'article_count': 12},
#  'se': {'total_count': 7, 'article_count': 6},
#  'y': {'total_count': 35, 'article_count': 15},
#  'Â': {'total_count': 72, 'article_count': 15},
#  'Ur': {'total_count': 2, 'article_count': 2},
#  'resolved': {'total_count': 2, 'article_count': 2},
#  'achieved': {'total_count': 2, 'article_count': 2},
#  'wing': {'total_count': 9, 'article_count': 6},
#  'rapidly': {'total_count': 4, 'article_count': 3},
#  'caused': {'total_count': 15, 'article_count': 11},
#  'surplus': {'total_count': 2, 'article_count': 1},
#  'money': {'total_count': 55, 'article_count': 20},
#  'begin': {'total_count': 10, 'article_count': 9},
#  'Py': {'total_count': 2, 'article_count': 2},
#  'government': {'total_count': 48, 'article_count': 12},
#  'revenue': {'total_count': 9, 'article_count': 3},
#  'tax': {'total_count': 14, 'article_count': 7},
#  'chasing': {'total_count': 2, 'article_count': 2},
#  'goods': {'total_count': 4, 'article_count': 4},
#  'Interest': {'total_count': 2, 'article_count': 2},
#  'grant': {'total_count': 6, 'article_count': 5},
#  'matter': {'total_count': 22, 'article_count': 13},
#  'aid': {'total_count': 16, 'article_count': 8},
#  'turn': {'total_count': 14, 'article_count': 11},
#  'price': {'total_count': 7, 'article_count': 5},
#  'fought': {'total_count': 5, 'article_count': 2},
#  'rates': {'total_count': 20, 'article_count': 6},
#  'growth': {'total_count': 7, 'article_count': 2},
#  'rising': {'total_count': 3, 'article_count': 3},
#  'market': {'total_count': 7, 'article_count': 2},
#  'forces': {'total_count': 19, 'article_count': 9},
#  'Spanish': {'total_count': 11, 'article_count': 6},
#  'w': {'total_count': 50, 'article_count': 16},
#  'raise': {'total_count': 6, 'article_count': 5},
#  'wrong': {'total_count': 8, 'article_count': 7},
#  'slow': {'total_count': 11, 'article_count': 7},
#  'h': {'total_count': 39, 'article_count': 15},
#  'Q': {'total_count': 26, 'article_count': 12},
#  'fell': {'total_count': 7, 'article_count': 5},
#  'editor': {'total_count': 7, 'article_count': 4},
#  'Vy': {'total_count': 2, 'article_count': 2},
#  'Li': {'total_count': 3, 'article_count': 3},
#  'Yes': {'total_count': 6, 'article_count': 5},
#  'decreased': {'total_count': 5, 'article_count': 1},
#  'remained': {'total_count': 6, 'article_count': 4},
#  'reader': {'total_count': 2, 'article_count': 1},
#  'counted': {'total_count': 2, 'article_count': 2},
#  'simply': {'total_count': 6, 'article_count': 4},
#  'dollars': {'total_count': 13, 'article_count': 10},
#  'par': {'total_count': 5, 'article_count': 5},
#  'valid': {'total_count': 2, 'article_count': 2},
#  'argument': {'total_count': 5, 'article_count': 4},
#  'comfortable': {'total_count': 2, 'article_count': 2},
#  'evening': {'total_count': 7, 'article_count': 5},
#  'fun': {'total_count': 6, 'article_count': 6},
#  'pa': {'total_count': 2, 'article_count': 2},
#  'consequence': {'total_count': 2, 'article_count': 2},
#  'decrease': {'total_count': 5, 'article_count': 1},
#  'jf': {'total_count': 6, 'article_count': 3},
#  'determined': {'total_count': 4, 'article_count': 4},
#  'French': {'total_count': 37, 'article_count': 13},
#  'possession': {'total_count': 2, 'article_count': 2},
#  'good': {'total_count': 54, 'article_count': 23},
#  'TVO': {'total_count': 12, 'article_count': 1},
#  'presumed': {'total_count': 2, 'article_count': 2},
#  'legal': {'total_count': 9, 'article_count': 7},
#  'movie': {'total_count': 10, 'article_count': 6},
#  'night': {'total_count': 49, 'article_count': 19},
#  'stage': {'total_count': 5, 'article_count': 3},
#  'school': {'total_count': 20, 'article_count': 12},
#  'educational': {'total_count': 3, 'article_count': 2},
#  'cent': {'total_count': 35, 'article_count': 19},
#  'set': {'total_count': 30, 'article_count': 19},
#  'knowledge': {'total_count': 5, 'article_count': 4},
#  'giving': {'total_count': 9, 'article_count': 8},
#  'right': {'total_count': 34, 'article_count': 19},
#  'range': {'total_count': 6, 'article_count': 5},
#  'grave': {'total_count': 4, 'article_count': 4},
#  'balance': {'total_count': 3, 'article_count': 3},
#  'na': {'total_count': 7, 'article_count': 6},
#  'da': {'total_count': 10, 'article_count': 6},
#  'changing': {'total_count': 5, 'article_count': 5},
#  'policy': {'total_count': 16, 'article_count': 7},
#  'sells': {'total_count': 3, 'article_count': 3},
#  'programs': {'total_count': 8, 'article_count': 4},
#  'e': {'total_count': 50, 'article_count': 17},
#  'Board': {'total_count': 9, 'article_count': 7},
#  'readers': {'total_count': 3, 'article_count': 3},
#  'tries': {'total_count': 8, 'article_count': 7},
#  'signal': {'total_count': 3, 'article_count': 3},
#  'increase': {'total_count': 12, 'article_count': 4},
#  'concept': {'total_count': 2, 'article_count': 2},
#  'rate': {'total_count': 20, 'article_count': 12},
#  'TV': {'total_count': 11, 'article_count': 9},
#  'screens': {'total_count': 3, 'article_count': 3},
#  'present': {'total_count': 19, 'article_count': 12},
#  'level': {'total_count': 9, 'article_count': 5},
#  'Vl': {'total_count': 3, 'article_count': 3},
#  'g': {'total_count': 68, 'article_count': 15},
#  'starved': {'total_count': 2, 'article_count': 2},
#  'funds': {'total_count': 6, 'article_count': 5},
#  'ally': {'total_count': 5, 'article_count': 5},
#  'maintained': {'total_count': 6, 'article_count': 5},
#  'vears': {'total_count': 3, 'article_count': 3},
#  'bv': {'total_count': 14, 'article_count': 8},
#  'Adam': {'total_count': 6, 'article_count': 3},
#  'Speaking': {'total_count': 4, 'article_count': 3},
#  'shameful': {'total_count': 2, 'article_count': 2},
#  'extent': {'total_count': 4, 'article_count': 4},
#  'past': {'total_count': 17, 'article_count': 13},
#  'late': {'total_count': 14, 'article_count': 11},
#  'turmoil': {'total_count': 2, 'article_count': 2},
#  'VI': {'total_count': 6, 'article_count': 6},
#  'Smith': {'total_count': 16, 'article_count': 8},
#  'increases': {'total_count': 4, 'article_count': 2},
#  'sion': {'total_count': 7, 'article_count': 7},
#  'suit': {'total_count': 8, 'article_count': 7},
#  'curriculum': {'total_count': 5, 'article_count': 2},
#  'materials': {'total_count': 5, 'article_count': 4},
#  'lower': {'total_count': 4, 'article_count': 3},
#  'Practical': {'total_count': 2, 'article_count': 2},
#  'wav': {'total_count': 5, 'article_count': 4},
#  'department': {'total_count': 7, 'article_count': 6},
#  'need': {'total_count': 34, 'article_count': 15},
#  'rr': {'total_count': 12, 'article_count': 10},
#  'growing': {'total_count': 9, 'article_count': 8},
#  'sales': {'total_count': 4, 'article_count': 4},
#  'cigarettes': {'total_count': 3, 'article_count': 3},
#  'onlv': {'total_count': 3, 'article_count': 3},
#  'suffered': {'total_count': 3, 'article_count': 3},
#  'erosion': {'total_count': 2, 'article_count': 1},
#  'says': {'total_count': 34, 'article_count': 18},
#  'Bernard': {'total_count': 2, 'article_count': 2},
#  'Ostry': {'total_count': 2, 'article_count': 1},
#  'fhe': {'total_count': 3, 'article_count': 3},
#  'Unfortunately': {'total_count': 2, 'article_count': 2},
#  'appointed': {'total_count': 7, 'article_count': 3},
#  'new': {'total_count': 79, 'article_count': 30},
#  'head': {'total_count': 15, 'article_count': 14},
#  'Premier': {'total_count': 8, 'article_count': 6},
#  'David': {'total_count': 22, 'article_count': 13},
#  'acute': {'total_count': 3, 'article_count': 3},
#  'inflation': {'total_count': 3, 'article_count': 3},
#  'true': {'total_count': 16, 'article_count': 9},
#  'Peterson': {'total_count': 7, 'article_count': 5},
#  'hide': {'total_count': 5, 'article_count': 5},
#  'gests': {'total_count': 2, 'article_count': 2},
#  'reach': {'total_count': 8, 'article_count': 7},
#  'eliminate': {'total_count': 4, 'article_count': 3},
#  'woman': {'total_count': 18, 'article_count': 11},
#  'feel': {'total_count': 17, 'article_count': 13},
#  'costs': {'total_count': 7, 'article_count': 5},
#  'reducing': {'total_count': 4, 'article_count': 2},
#  'allow': {'total_count': 11, 'article_count': 8},
#  'turbans': {'total_count': 3, 'article_count': 1},
#  'oi': {'total_count': 11, 'article_count': 8},
#  'nas': {'total_count': 4, 'article_count': 2},
#  'capital': {'total_count': 9, 'article_count': 7},
#  'cut': {'total_count': 12, 'article_count': 11},
#  'forms': {'total_count': 2, 'article_count': 2},
#  'media': {'total_count': 3, 'article_count': 3},
#  'popular': {'total_count': 9, 'article_count': 8},
#  'demand': {'total_count': 4, 'article_count': 3},
#  'increased': {'total_count': 9, 'article_count': 3},
#  'ments': {'total_count': 11, 'article_count': 8},
#  'public': {'total_count': 31, 'article_count': 18},
#  'send': {'total_count': 4, 'article_count': 4},
#  'find': {'total_count': 26, 'article_count': 16},
#  'views': {'total_count': 4, 'article_count': 4},
#  'needed': {'total_count': 11, 'article_count': 9},
#  'coming': {'total_count': 13, 'article_count': 13},
#  'vate': {'total_count': 4, 'article_count': 4},
#  'ment': {'total_count': 36, 'article_count': 20},
#  'spending': {'total_count': 11, 'article_count': 5},
#  'politicians': {'total_count': 5, 'article_count': 2},
#  'Queen': {'total_count': 12, 'article_count': 9},
#  'size': {'total_count': 6, 'article_count': 4},
#  'virtually': {'total_count': 2, 'article_count': 2},
#  'minute': {'total_count': 4, 'article_count': 4},
#  'chat': {'total_count': 2, 'article_count': 1},
#  'mortar': {'total_count': 3, 'article_count': 3},
#  'ideas': {'total_count': 3, 'article_count': 2},
#  'neglected': {'total_count': 3, 'article_count': 2},
#  'ernment': {'total_count': 10, 'article_count': 4},
#  'payments': {'total_count': 2, 'article_count': 2},
#  'today': {'total_count': 37, 'article_count': 12},
#  'learned': {'total_count': 9, 'article_count': 5},
#  'feels': {'total_count': 5, 'article_count': 3},
#  'strongly': {'total_count': 3, 'article_count': 3},
#  'mino': {'total_count': 2, 'article_count': 2},
#  'iu': {'total_count': 5, 'article_count': 5},
#  'ming': {'total_count': 3, 'article_count': 2},
#  'vu': {'total_count': 3, 'article_count': 2},
#  'aggressive': {'total_count': 2, 'article_count': 2},
#  'selling': {'total_count': 10, 'article_count': 7},
#  'labor': {'total_count': 17, 'article_count': 8},
#  'business': {'total_count': 12, 'article_count': 10},
#  'want': {'total_count': 21, 'article_count': 12},
#  'dian': {'total_count': 5, 'article_count': 4},
#  'Way': {'total_count': 4, 'article_count': 3},
#  'things': {'total_count': 20, 'article_count': 13},
#  'power': {'total_count': 21, 'article_count': 14},
#  'despite': {'total_count': 9, 'article_count': 8},
#  'effect': {'total_count': 12, 'article_count': 9},
#  'proven': {'total_count': 3, 'article_count': 3},
#  'tn': {'total_count': 12, 'article_count': 9},
#  'income': {'total_count': 10, 'article_count': 6},
#  'profits': {'total_count': 3, 'article_count': 3},
#  'able': {'total_count': 21, 'article_count': 14},
#  'image': {'total_count': 7, 'article_count': 4},
#  'change': {'total_count': 19, 'article_count': 16},
#  'police': {'total_count': 31, 'article_count': 15},
#  'ah': {'total_count': 2, 'article_count': 2},
#  'mat': {'total_count': 3, 'article_count': 2},
#  'cnange': {'total_count': 2, 'article_count': 2},
#  'increasing': {'total_count': 5, 'article_count': 3},
#  'unemployment': {'total_count': 4, 'article_count': 4},
#  'hope': {'total_count': 11, 'article_count': 9},
#  'reduction': {'total_count': 6, 'article_count': 4},
#  'tional': {'total_count': 12, 'article_count': 12},
#  'programming': {'total_count': 3, 'article_count': 1},
#  'areas': {'total_count': 10, 'article_count': 6},
#  'including': {'total_count': 24, 'article_count': 18},
#  'occurred': {'total_count': 9, 'article_count': 8},
#  'effects': {'total_count': 2, 'article_count': 2},
#  'paid': {'total_count': 12, 'article_count': 9},
#  'generation': {'total_count': 4, 'article_count': 2},
#  'secondary': {'total_count': 3, 'article_count': 2},
#  'post': {'total_count': 6, 'article_count': 5},
#  'training': {'total_count': 12, 'article_count': 8},
#  'adult': {'total_count': 2, 'article_count': 2},
#  'act': {'total_count': 18, 'article_count': 13},
#  'economy': {'total_count': 7, 'article_count': 6},
#  'example': {'total_count': 6, 'article_count': 5},
#  'proud': {'total_count': 3, 'article_count': 3},
#  'learning': {'total_count': 2, 'article_count': 2},
#  'staff': {'total_count': 6, 'article_count': 6},
#  'estimate': {'total_count': 4, 'article_count': 4},
#  'cial': {'total_count': 9, 'article_count': 7},
#  'percentage': {'total_count': 2, 'article_count': 2},
#  'like': {'total_count': 44, 'article_count': 24},
#  'walk': {'total_count': 7, 'article_count': 7},
#  'streets': {'total_count': 10, 'article_count': 7},
#  'cost': {'total_count': 21, 'article_count': 7},
#  'double': {'total_count': 6, 'article_count': 4},
#  'current': {'total_count': 10, 'article_count': 9},
#  'budget': {'total_count': 3, 'article_count': 3},
#  'reason': {'total_count': 15, 'article_count': 13},
#  'belief': {'total_count': 5, 'article_count': 5},
#  'points': {'total_count': 5, 'article_count': 5},
#  'save': {'total_count': 6, 'article_count': 5},
#  'federal': {'total_count': 13, 'article_count': 8},
#  'u': {'total_count': 66, 'article_count': 16},
#  'p': {'total_count': 44, 'article_count': 17},
#  'inn': {'total_count': 4, 'article_count': 4},
#  'ls': {'total_count': 7, 'article_count': 4},
#  'exactly': {'total_count': 5, 'article_count': 5},
#  'opposite': {'total_count': 3, 'article_count': 2},
#  'equivalent': {'total_count': 2, 'article_count': 2},
#  'ho': {'total_count': 22, 'article_count': 8},
#  'th': {'total_count': 38, 'article_count': 15},
#  'tire': {'total_count': 5, 'article_count': 5},
#  'undermine': {'total_count': 2, 'article_count': 2},
#  'taxes': {'total_count': 4, 'article_count': 4},
#  'ruin': {'total_count': 3, 'article_count': 3},
#  'healthy': {'total_count': 4, 'article_count': 4},
#  'interviewed': {'total_count': 2, 'article_count': 2},
#  'ine': {'total_count': 9, 'article_count': 7},
#  'plan': {'total_count': 17, 'article_count': 15},
#  'period': {'total_count': 9, 'article_count': 8},
#  'regain': {'total_count': 2, 'article_count': 2},
#  'iâ': {'total_count': 4, 'article_count': 4},
#  'fact': {'total_count': 23, 'article_count': 15},
#  'caus': {'total_count': 2, 'article_count': 2},
#  'counter': {'total_count': 3, 'article_count': 3},
#  'realize': {'total_count': 10, 'article_count': 8},
#  'lost': {'total_count': 13, 'article_count': 11},
#  'maintain': {'total_count': 2, 'article_count': 2},
#  'est': {'total_count': 4, 'article_count': 4},
#  'provided': {'total_count': 7, 'article_count': 6},
#  'excellent': {'total_count': 6, 'article_count': 5},
#  'service': {'total_count': 16, 'article_count': 12},
#  'schools': {'total_count': 8, 'article_count': 4},
#  'k': {'total_count': 38, 'article_count': 17},
#  'yield': {'total_count': 2, 'article_count': 2},
#  'lives': {'total_count': 17, 'article_count': 14},
#  'communities': {'total_count': 5, 'article_count': 5},
#  'Ontario': {'total_count': 52, 'article_count': 21},
#  'parts': {'total_count': 10, 'article_count': 8},
#  'ful': {'total_count': 3, 'article_count': 3},
#  'Metro': {'total_count': 18, 'article_count': 4},
#  'hp': {'total_count': 2, 'article_count': 2},
#  'preceded': {'total_count': 2, 'article_count': 2},
#  'tne': {'total_count': 13, 'article_count': 8},
#  'doesn': {'total_count': 2, 'article_count': 2},
#  'published': {'total_count': 8, 'article_count': 6},
#  'ue': {'total_count': 2, 'article_count': 2},
#  'review': {'total_count': 7, 'article_count': 6},
#  'nr': {'total_count': 8, 'article_count': 4},
#  'events': {'total_count': 6, 'article_count': 6},
#  'shows': {'total_count': 9, 'article_count': 6},
#  'writers': {'total_count': 2, 'article_count': 2},
#  'le': {'total_count': 9, 'article_count': 7},
#  'beland': {'total_count': 2, 'article_count': 1},
#  'ii': {'total_count': 24, 'article_count': 14},
#  'tors': {'total_count': 2, 'article_count': 2},
#  'devoted': {'total_count': 3, 'article_count': 3},
#  'Lo': {'total_count': 3, 'article_count': 2},
#  'ship': {'total_count': 7, 'article_count': 6},
#  'words': {'total_count': 10, 'article_count': 9},
#  'issue': {'total_count': 12, 'article_count': 9},
#  'president': {'total_count': 20, 'article_count': 14},
#  'Book': {'total_count': 2, 'article_count': 2},
#  'headline': {'total_count': 3, 'article_count': 1},
#  'writer': {'total_count': 5, 'article_count': 5},
#  'Direct': {'total_count': 3, 'article_count': 3},
#  'page': {'total_count': 5, 'article_count': 3},
#  'storv': {'total_count': 3, 'article_count': 2},
#  'Parliament': {'total_count': 4, 'article_count': 4},
#  'secret': {'total_count': 4, 'article_count': 4},
#  'D': {'total_count': 23, 'article_count': 10},
#  'week': {'total_count': 53, 'article_count': 24},
#  'winter': {'total_count': 7, 'article_count': 6},
#  'MPs': {'total_count': 3, 'article_count': 3},
#  'F': {'total_count': 21, 'article_count': 7},
#  'method': {'total_count': 4, 'article_count': 3},
#  'named': {'total_count': 10, 'article_count': 8},
#  'sources': {'total_count': 7, 'article_count': 5},
#  'warm': {'total_count': 5, 'article_count': 5},
#  'weather': {'total_count': 8, 'article_count': 6},
#  'Mexico': {'total_count': 3, 'article_count': 3},
#  'logical': {'total_count': 3, 'article_count': 3},
#  'Executive': {'total_count': 5, 'article_count': 2},
#  'community': {'total_count': 28, 'article_count': 14},
#  'East': {'total_count': 18, 'article_count': 8},
#  'Parliamentary': {'total_count': 3, 'article_count': 2},
#  'Relations': {'total_count': 2, 'article_count': 2},
#  'supply': {'total_count': 2, 'article_count': 2},
#  'vice': {'total_count': 2, 'article_count': 2},
#  'ed': {'total_count': 33, 'article_count': 18},
#  'slain': {'total_count': 2, 'article_count': 2},
#  'newspaper': {'total_count': 7, 'article_count': 4},
#  'x': {'total_count': 15, 'article_count': 7},
#  'agent': {'total_count': 5, 'article_count': 2},
#  'details': {'total_count': 3, 'article_count': 3},
#  'know': {'total_count': 28, 'article_count': 18},
#  'sure': {'total_count': 10, 'article_count': 10},
#  'trips': {'total_count': 4, 'article_count': 2},
#  'requires': {'total_count': 3, 'article_count': 3},
#  'taken': {'total_count': 30, 'article_count': 17},
#  'taxpayers': {'total_count': 2, 'article_count': 2},
#  'expense': {'total_count': 4, 'article_count': 4},
#  'nave': {'total_count': 3, 'article_count': 3},
#  'merit': {'total_count': 4, 'article_count': 3},
#  'understanding': {'total_count': 2, 'article_count': 2},
#  'ruth': {'total_count': 2, 'article_count': 2},
#  'imposed': {'total_count': 5, 'article_count': 5},
#  'freeze': {'total_count': 3, 'article_count': 3},
#  'non': {'total_count': 6, 'article_count': 6},
#  'essential': {'total_count': 2, 'article_count': 2},
#  'william': {'total_count': 2, 'article_count': 1},
#  'pro': {'total_count': 6, 'article_count': 6},
#  'travel': {'total_count': 5, 'article_count': 5},
#  'servants': {'total_count': 2, 'article_count': 2},
#  'possible': {'total_count': 21, 'article_count': 16},
#  'ways': {'total_count': 8, 'article_count': 7},
#  'Romania': {'total_count': 2, 'article_count': 2},
#  'akin': {'total_count': 2, 'article_count': 2},
#  'thp': {'total_count': 4, 'article_count': 4},
#  'tamp': {'total_count': 2, 'article_count': 2},
#  'nn': {'total_count': 11, 'article_count': 10},
#  'mm': {'total_count': 14, 'article_count': 9},
#  'theory': {'total_count': 5, 'article_count': 4},
#  'taking': {'total_count': 16, 'article_count': 10},
#  'supported': {'total_count': 7, 'article_count': 6},
#  'Japan': {'total_count': 5, 'article_count': 3},
#  'Western': {'total_count': 15, 'article_count': 9},
#  'decision': {'total_count': 14, 'article_count': 8},
#  'view': {'total_count': 13, 'article_count': 11},
#  'rope': {'total_count': 3, 'article_count': 3},
#  'Bank': {'total_count': 14, 'article_count': 6},
#  'Gordon': {'total_count': 5, 'article_count': 5},
#  'disapproval': {'total_count': 3, 'article_count': 3},
#  'recent': {'total_count': 15, 'article_count': 12},
#  'lent': {'total_count': 6, 'article_count': 5},
#  'election': {'total_count': 14, 'article_count': 7},
#  'office': {'total_count': 13, 'article_count': 10},
#  'john': {'total_count': 2, 'article_count': 1},
#  'gave': {'total_count': 7, 'article_count': 6},
#  'Keeping': {'total_count': 2, 'article_count': 2},
#  ...}

# %%
vocab_path = 
assert os.path.exists(vocab_path)

# %%
# Out:
# Vocab size after removing terms that appear less than i articles
#  i,    size
#  0:   10880
#  1:    2201
#  2:     992
#  3:     537
#  4:     306
#  5:     176
#  6:     100
#  7:      65
#  8:      37
#  9:      21
# 10:      12
# 11:       7
# 12:       7
# 13:       3
# 14:       2
# 15:       1
# 16:       1
# 17:       1
# 18:       0
# 19:       0
# 20:       0
# 21:       0
# 22:       0
# 23:       0
# 24:       0
# 25:       0
# 26:       0
# 27:       0
# 28:       0
# 29:       0
# 30:       0
# 31:       0
# 32:       0
# 33:       0
# 34:       0
# 35:       0
# 36:       0
# 37:       0
# 38:       0
# 39:       0
# 40:       0

# %%
print(f'Vocab size after removing terms that appear less than i articles')
print(' i,    size')
for i in range(41):
    print(f'{i:2}:   {len([word for word in total_count if total_count[word]>i]):5}')
# Out:
# Vocab size after removing terms that appear less than i articles
#  i,    size
#  0:   10880
#  1:    3085
#  2:    1674
#  3:    1090
#  4:     762
#  5:     557
#  6:     437
#  7:     362
#  8:     294
#  9:     257
# 10:     217
# 11:     183
# 12:     152
# 13:     132
# 14:     117
# 15:      95
# 16:      88
# 17:      78
# 18:      73
# 19:      65
# 20:      60
# 21:      53
# 22:      49
# 23:      48
# 24:      46
# 25:      41
# 26:      37
# 27:      33
# 28:      32
# 29:      31
# 30:      28
# 31:      27
# 32:      26
# 33:      25
# 34:      24
# 35:      24
# 36:      22
# 37:      22
# 38:      21
# 39:      21
# 40:      20

# %%
[word for word in freq if freq[word]>40]
# Out:
# ['year',
#  's',
#  'day',
#  'St',
#  'time',
#  'Toronto',
#  'S',
#  'm',
#  'J',
#  'j',
#  't',
#  'f',
#  'M',
#  'r',
#  'n',
#  'Jersey',
#  'H',
#  'B',
#  'Reg',
#  'CD']

# %%
# Creating three lists to store filename, fulltext, and date
# In TDM studio - the article ID is the same as the filename

# text_list = []
date_list = []

# Parse files and add data to lists
vocab = set()
token2idx = {}
for file in files:
    tree = etree.parse(data_path + file)
    root = tree.getroot()
    
    if getxmlcontent(root) is not None:
        soup = BeautifulSoup(getxmlcontent(root))
        text = soup.get_text()
        for token in nlp(text):
            if not token.is_stop and token.is_alpha:
                if not token in vocab:
                    token2idx[token.text]=len(vocab)
                    vocab.add(token)
    else:
        text = 'Error in processing document'
        
    date = root.find('.//NumericDate').text
    
#     filename_list.append(file)
#     text_list.append(text)
    date_list.append(date)
# print(text_list[0])
print(date_list[0])
print(len(vocab))

# %%
print(text_list[0])
print(date_list[0])
# Out:
#
#
#
#
# On The Highways of Sport
#
#
# BY RODDEN Sports Editor ot The Globe
#
#
# Leafs Beat Keys and Crowd Leaders
#
#
# Fifteen hits rang off Leaf bats at Beading yesterday as the O'Neillmen defeated the Keystones by 11 to 5, and advanced into third place only half game behind the league-leading Royals and Orioles Frank Barnes went the route for the invaders and won his second consecutive start and it is evident that the big lefthander is headed for successful season
#
#
# Little Harry Davis stole the sluggers' thunder when he connected for four safeties one of them being homer his second in as many days Davis has had hard fight of it this year with Jimmy Shevlin available for first-base duty but if he continues to clout that ball his troubles will be over As fielder he stands alone being another Mickey Heath Baltimore and Rochester staged ten-inning duel before the Orioles finally emerged- with- 4-to-3 victory It was close call for the Southerners troner s home run in the ninth enabling them to tie the score and avert defeat It was also the only hi made by Stroner The Royals kept pace with the Birds when they vanquished the Skeeters by 13 to 6. In this game Gautreau of Montreal and West and Sheedy of the Jerseys connected for the circuit Shcedy's homers when with the Leafs came few and far between but in the days when he was playing for the Orioles he was quite long-distance hitter The Bisons who have made great showing on the road and who are only one game behind the leaders rallied in the eighth inning to tie the score against Newark but the Bears came back with three in the same frame and won by 6 to 3. Manager Mamaux used three hurlers and Myles Thomas the last to go to tile hilltop was credited with the victory Wesley Ferrell Indian Ace Holds Browns Hitless Wesley Ferrell entered baseball s Hall of Fame at Cleveland yester day when he turned back the St Louis Browns without hit or run The great righthander was slightly wild and walked three batsmen while as many others reached first base owing to errors but none of the Browns got as far as the midway station It was Ferrell's fourth victory of the season almost half the Indians' total of nine As Washington the New York Yankees came to grief again the score being 9 to 5, and it becomes more apparent every day that Babe Ruth is nearly the entire Yankee team McCarthy's men have travelled rocky road since the big slugger was laid low at Boston Al Thomas was in old-time form and blanked the Detroit Tigers 3 to 0, at Comiskey Park In the meantime the Athletics and the Red Sox were kept idle at Boston owing to rain The defeat of the Bengals however sent the world s champions into the first division where they rest in fourth place three games behind the pace-setting Indians 1 Only two games were played in the National and in those the Chicago Cubs defeated the Cincinnati Reds by 3 to 1 and the Cardinals stopped Pittsburg 7 to 1. The winning teams thus remain deadlocked for first 1 place 1 Dan Howley is getting bad break at Cincinnati where he is trying to make headway with team that lacks class The owners are willing to buy star players but the other clubs refuse to sell with the result that Howley's team will likely remain consistent loser Oshawa Seniors Play Again in Series At meeting held yesterday Oshawa Lacrosse Club officials definite- Jy decided to operate teams in the senior and intermediate series this season and this means that there will be six teams in the senior division the starters bsing as follows Brampton Mimico Hamll- ton Oshawa Toronto St Simon's and Toronto Native Sons 1 It had been reported that several star players who will now have to line up with Oshawa or remain in idleness had intended joining Native Sons Seven high-class performers-- Kelly DeGray Bob Stephenson Alex Hall Pat Shannon Bill Coulter Chuck Davidson and Bill Spencer will be with Oshawa and there is no dearth of material to fill the other gaps Time works great changes in lacrosse just as well as in other sports and in this connection it is interesting to recall that the Oshawa team than wen the Mann Cup emblematic of the Canadian championship two years ago was hailed as one of the best in history Last year this team won the Lally Cup in the international games against the United States all-stars but when Brampton dethroned them the break-up came Oshawa officials believe that another powerful squad can be assembled and they are enthusiastic over prospects Brampto ...
#
#
#
#
# 1931-04-30

# %%
longer_word = ''
for text in text_list:
    inicio = len(vocab)
    for token in nlp(text):
        if not token.is_stop and token.is_alpha:
            if len(token.text)>20:
                print(token.text)

                
longer_word

# %%
vocab = set()
aumentos=[]
for text in text_list[:50]:
    inicio = len(vocab)
    for token in nlp(text):
        if not token.is_stop and token.is_alpha:
            vocab.add(token.text)
    print(f'+{len(vocab)-inicio}  (total: {len(vocab)})')
    aumentos.append(len(vocab)-inicio)
sum(aumentos)/len(aumentos)
# Out:
# +513  (total: 513)
# +933  (total: 1446)
# +1814  (total: 3260)
# +244  (total: 3504)
# +1587  (total: 5091)
# +197  (total: 5288)
# +227  (total: 5515)
# +121  (total: 5636)
# +703  (total: 6339)
# +159  (total: 6498)
# +422  (total: 6920)
# +555  (total: 7475)
# +296  (total: 7771)
# +881  (total: 8652)
# +744  (total: 9396)
# +86  (total: 9482)
# +102  (total: 9584)
# +108  (total: 9692)
# +919  (total: 10611)
# +269  (total: 10880)
# +1015  (total: 11895)
# +912  (total: 12807)
# +511  (total: 13318)
# +364  (total: 13682)
# +582  (total: 14264)
# +645  (total: 14909)
# +566  (total: 15475)
# +90  (total: 15565)
# +169  (total: 15734)
# +185  (total: 15919)
# +522  (total: 16441)
# +193  (total: 16634)
# +134  (total: 16768)
# +154  (total: 16922)
# +325  (total: 17247)
# +51  (total: 17298)
# +216  (total: 17514)
# +94  (total: 17608)
# +45  (total: 17653)
# +428  (total: 18081)
# +104  (total: 18185)
# +63  (total: 18248)
# +107  (total: 18355)
# +199  (total: 18554)
# +927  (total: 19481)
# +149  (total: 19630)
# +231  (total: 19861)
# +240  (total: 20101)
# +289  (total: 20390)
# +855  (total: 21245)
# 424.9

# %%
import spacy

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

# %%
for t in doc:
    if not t.is_stop and t.is_alpha:        
        print(t)
# Out:
# Apple
# looking
# buying
# startup
# billion

# %%
t.text
# Out:
# 'billion'

# %%
# !conda install -y lxml
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
import spacy
