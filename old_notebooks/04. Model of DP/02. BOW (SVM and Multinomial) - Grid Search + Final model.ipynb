# %% [markdown]
# ## Aux functions

# %%
from IPython.core.display import display, HTML
import datetime
def info(str_):
    print(f'{datetime.datetime.now()} [ \033[1;94mINFO\x1b[0m  ] {str_}')
def ok(str_):
    print(f'{datetime.datetime.now()} [  \033[1;92mOK\x1b[0m   ] {str_}')
def warning(str_):
    print(f'{datetime.datetime.now()} [\x1b[1;31mWARNING\x1b[0m] {str_}')
def html(str_=''):
    display(HTML(str_))

# %%
import pandas as pd
from lxml import etree
from bs4 import BeautifulSoup

def get_date(filename):
    tree = etree.parse(filename)
    root = tree.getroot()
#     title = root.find('.//Title').text
    date = root.find('.//NumericDate').text
#     publisher = root.find('.//PublisherName').text
    assert date is not None
    
    return date

def get_title_and_text(filename):
    tree = etree.parse(filename)
    root = tree.getroot()
    if root.find('.//HiddenText') is not None:
        text = (root.find('.//HiddenText').text)

    elif root.find('.//Text') is not None:
        text = (root.find('.//Text').text)

    else:
        text = None
                       
    title = root.find('.//Title')
    if title is not None:
        title = title.text
    if not text is None:
        text = BeautifulSoup(text, parser='html.parser').get_text()

    return title,text

# %% [markdown]
# ## Retrieving Label data

# %%
import os
DP_examples_dirpath = '/home/ec2-user/SageMaker/mariano/notebooks/04. Model of DP/DP-relevant articles/'
assert os.path.exists(DP_examples_dirpath)
files = []
for dirpath, dirnames, filenames in os.walk(DP_examples_dirpath):
    for filename in filenames:
        filepath = os.path.join(dirpath,filename)
        assert os.path.isfile(filepath)
        files.append(filepath)
info(f'Number of files retrieved: {len(files)}')
# Out:
# 2022-02-25 20:31:23.670807 [ INFO  ] Number of files retrieved: 11

# %%
import re
total_count=0
urls = []
ids = []
for file_ in files:
    content = open(file_, 'r').read()
    urls += re.findall('url = {(.*)}',content)
    ids += re.findall('/docview/([^/]*)/',content)
    total_count += len(urls)
    assert len(ids)==len(urls)

relevant_ids = set(ids)
# print(len(urls))
info(f'Relevant article count: {len(relevant_ids)}')
# Out:
# 2022-02-25 20:31:24.167651 [ INFO  ] Relevant article count: 535

# %% [markdown]
# ## Reading files from disk

# %%
import os
GM_all_part1 = '/home/ec2-user/SageMaker/data/GM_all_1945_1956/'
GM_all_part2 = '/home/ec2-user/SageMaker/data/GM_all_1957-1967/'
GM_dp_dirpath = '/home/ec2-user/SageMaker/data/GM_DP_and_Canada1945_1967/'

all_files = [GM_all_part1+file_ for file_ in os.listdir(GM_all_part1)]
all_files += [GM_all_part2+file_ for file_ in os.listdir(GM_all_part2)]

dp_files = [GM_dp_dirpath+file_ for file_ in os.listdir(GM_dp_dirpath)]

# GM_dirpath = '/home/ec2-user/SageMaker/data/The_Globe_and_Mail_with_DP_filter_by_article_type/'
# all_files = [TS_dirpath+file_id for file_id in os.listdir(TS_dirpath)]
# all_files += [GM_dirpath+file_id for file_id in os.listdir(GM_dirpath)]

info(f'len(all_files):       {len(all_files):10,}')
info(f'len(dp_files):        {len(dp_files):10,}')
# Out:
# 2022-02-25 20:31:29.504543 [ INFO  ] len(all_files):        2,057,868
# 2022-02-25 20:31:29.504718 [ INFO  ] len(dp_files):             6,938

# %% [markdown]
# #### Creating dataframe with ids + 'unknown' label

# %%
import pandas as pd
dp_articles_df = pd.DataFrame(
                  ['unknown']*len(dp_files), 
                  columns=['label']
                 )
dp_articles_df['id'] = [file_id.split('/')[-1][:-4] for file_id in dp_files]
# df['source']='GM'
# df.iloc[:len(os.listdir(TS_dirpath)),-1]='TS'
dp_articles_df
# Out:
#         label          id
# 0     unknown  1287338646
# 1     unknown  1270339579
# 2     unknown  1287501005
# 3     unknown  1289163109
# 4     unknown  1289176186
# ...       ...         ...
# 6933  unknown  1282757714
# 6934  unknown  1270441158
# 6935  unknown  1288866985
# 6936  unknown  1356078942
# 6937  unknown  1288480618
#
# [6938 rows x 2 columns]

# %% [markdown]
# #### Adding correct label + date to DataFrame

# %%
import numpy as np

relevants=0
dates = []

for idx,file_ in enumerate(dp_files):
    id_ = file_.split('/')[-1][:-4]
    date = get_date(file_)
    year = int(date[:4])
    if id_ in relevant_ids:
        dp_articles_df.iloc[idx,0]='relevant'
        relevants+=1
    else:
        dp_articles_df.iloc[idx,0]='irrelevant'
        
    dates.append(date)
dp_articles_df['date']=dates
info(f"Number of relevants:   {np.sum(dp_articles_df['label']=='relevant'):,}")
info(f"Number of irrelevants: {np.sum(dp_articles_df['label']=='irrelevant'):,}")
info(f"'Number of unknown:    {np.sum(dp_articles_df['label']=='unknown'):,}")
dp_articles_df
# Out:
# 2022-02-25 20:31:38.596265 [ INFO  ] Number of relevants:   514
# 2022-02-25 20:31:38.603277 [ INFO  ] Number of irrelevants: 6,424
# 2022-02-25 20:31:38.607630 [ INFO  ] 'Number of unknown:    0
#            label          id        date
# 0     irrelevant  1287338646  1951-03-15
# 1     irrelevant  1270339579  1965-02-17
# 2     irrelevant  1287501005  1958-02-18
# 3     irrelevant  1289163109  1956-10-13
# 4     irrelevant  1289176186  1954-03-27
# ...          ...         ...         ...
# 6933  irrelevant  1282757714  1963-04-19
# 6934  irrelevant  1270441158  1965-05-14
# 6935  irrelevant  1288866985  1957-11-19
# 6936  irrelevant  1356078942  1963-10-12
# 6937  irrelevant  1288480618  1960-06-28
#
# [6938 rows x 3 columns]

# %% [markdown]
# ### SVM with average GloVe

# %% [markdown]
# #### Generating VOCAB

# %%
import spacy
import pickle
import string
from tqdm import tqdm
nlp = spacy.load('en_core_web_lg', disable=['textcat','lemmatizer', 'parser', 'tagger','ner'])

def remove_punctuation(word):
    return ''.join([char for char in word if not char in string.punctuation+' '])

def tokenize(str_):
    tokens = [word.text.lower() for word in nlp(str_) if not word.is_stop]
    tokens = [word.replace('\n', '') for word in tokens if not word.isnumeric() and len(remove_punctuation(word))!=0]
    return tokens



def build_vocab(file_list, umbral=None,threshold=10000):
    if os.path.isfile('cache/vocab.p'):
        vocab = pickle.load(open('cache/vocab.p', 'rb'))
    else:
        visited = set()
        freq = {}
        for file_ in tqdm(file_list):
            title, text = get_title_and_text(file_)
            tokens = tokenize(title+' '+text)
            for token in tokens:
                if token in visited:
                    if not token in freq:
                        freq[token]=2
                    else:
                        freq[token]+=1
                else:
                    visited.add(token)
        word_frequency_list = [(word, freq[word]) for word in freq if not word.strip()=='' and len(word)>=3]
        word_frequency_list = sorted(word_frequency_list, key=lambda x: x[1],reverse=True)
        vocab = [word for word,_ in word_frequency_list[:threshold]]

        pickle.dump(vocab,open('cache/vocab.p', 'wb'))        
        del(freq)
        del(word_frequency_list)
        del(visited)
    return vocab
vocab = build_vocab(dp_files)
len(vocab)
# Out:
# 10000

# %% [markdown]
# #### Generating X, y for training model (involves look-up for GloVe vectors (spacy nlp))

# %%
   
if os.path.isfile('cache/X_bow.p') and os.path.isfile('cache/y_bow.p'):
    info('Retrieving from disk')
    X = pickle.load(open('cache/X_bow.p','rb'))
    y = pickle.load(open('cache/y_bow.p', 'rb'))
else:
    info('Creating X and y')
    vocab = build_vocab(dp_files)
    word2idx = dict([(word,idx) for idx, word in enumerate(vocab)])
    example_no = np.sum(dp_articles_df["label"]!='unknown')

    X = np.zeros(shape=(example_no, len(vocab)+1), dtype='float32')
    y = np.zeros(shape=(example_no,), dtype='int32')

    inst_no=0
    for idx in tqdm(list(range(len(dp_articles_df)))):
        label, id_, date = dp_articles_df.iloc[idx,:]
        file_ = GM_dp_dirpath+id_+'.xml'

        assert label!='unknown'
        title, text = get_title_and_text(file_)
        tokens = tokenize(title+' '+text)
        for token in tokens:
            if token in word2idx:
                X[inst_no, word2idx[token]]+=1
            else:
                X[inst_no,-1]+=1
#         X[inst_no,:300] = nlp(title).vector
#         X[inst_no,300:] = nlp(text).vector
        y[inst_no] = 1 if label=='relevant' else 0
        inst_no+=1

    pickle.dump(X, open('cache/X_bow.p','wb'))
    pickle.dump(y, open('cache/y_bow.p','wb'))
# Out:
# 2022-02-25 20:31:46.135771 [ INFO  ] Retrieving from disk

# %%
# !rm cache/X_bow.p cache/y_bow.p

# %% [markdown]
# #### Grid Search SVM with BOW

# %%
from sklearn.model_selection import cross_validate
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
parameters = {'kernel':['linear', 'rbf', 'poly'],'C':[1,2,3,4,5,6]} #'degree':[1,2,3,4,5,6,7]}
svc = SVC()
clf = GridSearchCV(svc, parameters,scoring='f1', cv=5,verbose=4)

results = clf.fit(X,y)
pd.DataFrame(results.cv_results_)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END ................C=1, kernel=linear;, score=0.890 total time=  21.0s
# [CV 2/5] END ................C=1, kernel=linear;, score=0.861 total time=  21.5s
# [CV 3/5] END ................C=1, kernel=linear;, score=0.833 total time=  20.4s
# [CV 4/5] END ................C=1, kernel=linear;, score=0.865 total time=  22.5s
# [CV 5/5] END ................C=1, kernel=linear;, score=0.834 total time=  21.2s
# [CV 1/5] END ...................C=1, kernel=rbf;, score=0.000 total time=  54.9s
# [CV 2/5] END ...................C=1, kernel=rbf;, score=0.000 total time=  55.0s
# [CV 3/5] END ...................C=1, kernel=rbf;, score=0.000 total time=  55.1s
# [CV 4/5] END ...................C=1, kernel=rbf;, score=0.000 total time=  55.1s
# [CV 5/5] END ...................C=1, kernel=rbf;, score=0.000 total time=  55.8s
# [CV 1/5] END ..................C=1, kernel=poly;, score=0.000 total time=  35.0s
# [CV 2/5] END ..................C=1, kernel=poly;, score=0.000 total time=  35.0s
# [CV 3/5] END ..................C=1, kernel=poly;, score=0.000 total time=  35.2s
# [CV 4/5] END ..................C=1, kernel=poly;, score=0.000 total time=  35.0s
# [CV 5/5] END ..................C=1, kernel=poly;, score=0.000 total time=  35.3s
# [CV 1/5] END ................C=2, kernel=linear;, score=0.890 total time=  20.1s
# [CV 2/5] END ................C=2, kernel=linear;, score=0.861 total time=  21.2s
# [CV 3/5] END ................C=2, kernel=linear;, score=0.833 total time=  20.3s
# [CV 4/5] END ................C=2, kernel=linear;, score=0.865 total time=  21.2s
# [CV 5/5] END ................C=2, kernel=linear;, score=0.834 total time=  20.4s
# [CV 1/5] END ...................C=2, kernel=rbf;, score=0.000 total time=  55.4s
# [CV 2/5] END ...................C=2, kernel=rbf;, score=0.000 total time=  55.0s
# [CV 3/5] END ...................C=2, kernel=rbf;, score=0.000 total time=  54.6s
# [CV 4/5] END ...................C=2, kernel=rbf;, score=0.000 total time=  56.0s
# [CV 5/5] END ...................C=2, kernel=rbf;, score=0.000 total time=  55.7s
# [CV 1/5] END ..................C=2, kernel=poly;, score=0.000 total time=  36.1s
# [CV 2/5] END ..................C=2, kernel=poly;, score=0.000 total time=  36.4s
# [CV 3/5] END ..................C=2, kernel=poly;, score=0.000 total time=  35.6s
# [CV 4/5] END ..................C=2, kernel=poly;, score=0.000 total time=  35.8s
# [CV 5/5] END ..................C=2, kernel=poly;, score=0.000 total time=  36.1s
# [CV 1/5] END ................C=3, kernel=linear;, score=0.890 total time=  20.4s
# [CV 2/5] END ................C=3, kernel=linear;, score=0.861 total time=  21.9s
# [CV 3/5] END ................C=3, kernel=linear;, score=0.833 total time=  20.3s
# [CV 4/5] END ................C=3, kernel=linear;, score=0.865 total time=  21.2s
# [CV 5/5] END ................C=3, kernel=linear;, score=0.834 total time=  20.7s
# [CV 1/5] END ...................C=3, kernel=rbf;, score=0.000 total time=  55.6s
# [CV 2/5] END ...................C=3, kernel=rbf;, score=0.000 total time=  53.8s
# [CV 3/5] END ...................C=3, kernel=rbf;, score=0.000 total time=  54.5s
# [CV 4/5] END ...................C=3, kernel=rbf;, score=0.000 total time=  56.1s
# [CV 5/5] END ...................C=3, kernel=rbf;, score=0.000 total time=  55.7s
# [CV 1/5] END ..................C=3, kernel=poly;, score=0.000 total time=  35.9s
# [CV 2/5] END ..................C=3, kernel=poly;, score=0.000 total time=  37.4s
# [CV 3/5] END ..................C=3, kernel=poly;, score=0.000 total time=  36.7s
# [CV 4/5] END ..................C=3, kernel=poly;, score=0.000 total time=  36.6s
# [CV 5/5] END ..................C=3, kernel=poly;, score=0.000 total time=  36.4s
# [CV 1/5] END ................C=4, kernel=linear;, score=0.890 total time=  20.4s
# [CV 2/5] END ................C=4, kernel=linear;, score=0.861 total time=  21.4s
# [CV 3/5] END ................C=4, kernel=linear;, score=0.833 total time=  21.1s
# [CV 4/5] END ................C=4, kernel=linear;, score=0.865 total time=  22.0s
# [CV 5/5] END ................C=4, kernel=linear;, score=0.834 total time=  20.6s
# [CV 1/5] END ...................C=4, kernel=rbf;, score=0.000 total time=  56.5s
# [CV 2/5] END ...................C=4, kernel=rbf;, score=0.000 total time=  59.1s
# [CV 3/5] END ...................C=4, kernel=rbf;, score=0.000 total time=  56.6s
# [CV 4/5] END ...................C=4, kernel=rbf;, score=0.000 total time=  57.7s
# [CV 5/5] END ...................C=4, kernel=rbf;, score=0.000 total time=  57.0s
# [CV 1/5] END ..................C=4, kernel=poly;, score=0.000 total time=  58.0s
# [CV 2/5] END ..................C=4, kernel=poly;, score=0.000 total time=  46.7s
# [CV 3/5] END ..................C=4, kernel=poly;, score=0.000 total time=  35.5s
# [CV 4/5] END ..................C=4, kernel=poly;, score=0.000 total time=  36.3s
# [CV 5/5] END ..................C=4, kernel=poly;, score=0.000 total time=  36.2s
# [CV 1/5] END ................C=5, kernel=linear;, score=0.890 total time=  20.5s
# [CV 2/5] END ................C=5, kernel=linear;, score=0.861 total time=  21.4s
# [CV 3/5] END ................C=5, kernel=linear;, score=0.833 total time=  20.2s
# [CV 4/5] END ................C=5, kernel=linear;, score=0.865 total time=  21.1s
# [CV 5/5] END ................C=5, kernel=linear;, score=0.834 total time=  20.3s
# [CV 1/5] END ...................C=5, kernel=rbf;, score=0.000 total time=  55.5s
# [CV 2/5] END ...................C=5, kernel=rbf;, score=0.000 total time= 1.2min
# [CV 3/5] END ...................C=5, kernel=rbf;, score=0.000 total time=  56.6s
# [CV 4/5] END ...................C=5, kernel=rbf;, score=0.000 total time=  56.0s
# [CV 5/5] END ...................C=5, kernel=rbf;, score=0.000 total time=  55.8s
# [CV 1/5] END ..................C=5, kernel=poly;, score=0.000 total time=  36.9s
# [CV 2/5] END ..................C=5, kernel=poly;, score=0.000 total time=  36.4s
# [CV 3/5] END ..................C=5, kernel=poly;, score=0.000 total time=  36.7s
# [CV 4/5] END ..................C=5, kernel=poly;, score=0.000 total time=  36.1s
# [CV 5/5] END ..................C=5, kernel=poly;, score=0.000 total time=  37.4s
# [CV 1/5] END ................C=6, kernel=linear;, score=0.890 total time=  20.4s
# [CV 2/5] END ................C=6, kernel=linear;, score=0.861 total time=  21.7s
# [CV 3/5] END ................C=6, kernel=linear;, score=0.833 total time=  20.5s
# [CV 4/5] END ................C=6, kernel=linear;, score=0.865 total time=  21.8s
# [CV 5/5] END ................C=6, kernel=linear;, score=0.834 total time=  20.4s
# [CV 1/5] END ...................C=6, kernel=rbf;, score=0.000 total time=  55.2s
# [CV 2/5] END ...................C=6, kernel=rbf;, score=0.000 total time=  56.5s
# [CV 3/5] END ...................C=6, kernel=rbf;, score=0.000 total time=  55.2s
# [CV 4/5] END ...................C=6, kernel=rbf;, score=0.000 total time=  54.9s
# [CV 5/5] END ...................C=6, kernel=rbf;, score=0.000 total time=  54.7s
# [CV 1/5] END ..................C=6, kernel=poly;, score=0.000 total time=  36.8s
# [CV 2/5] END ..................C=6, kernel=poly;, score=0.000 total time=  36.4s
# [CV 3/5] END ..................C=6, kernel=poly;, score=0.000 total time=  36.5s
# [CV 4/5] END ..................C=6, kernel=poly;, score=0.000 total time=  36.4s
# [CV 5/5] END ..................C=6, kernel=poly;, score=0.000 total time=  36.6s
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       17.754612      0.700130         3.557973        0.083008       1
# 1       30.091866      0.287813        25.092628        0.423950       1
# 2       28.234112      0.118272         6.860139        0.054602       1
# 3       17.152460      0.416282         3.482776        0.071671       2
# 4       30.250049      0.328056        25.080581        0.577529       2
# 5       28.880580      0.362523         7.115195        0.259857       2
# 6       17.403991      0.542065         3.500034        0.075561       3
# 7       30.122188      0.427892        25.004455        0.492593       3
# 8       29.211161      0.305336         7.389111        0.626353       3
# 9       17.550020      0.566705         3.550072        0.081094       4
# 10      31.361310      0.563209        26.008505        0.476055       4
# 11      33.570395      5.586904         8.980918        3.889903       4
# 12      17.185024      0.442932         3.531911        0.052332       5
# 13      33.861799      5.617443        25.132828        0.466024       5
# 14      29.532143      0.349240         7.155982        0.132134       5
# 15      17.451073      0.642661         3.517505        0.086055       6
# 16      30.304640      0.205163        24.991970        0.489096       6
# 17      29.391231      0.107583         7.150559        0.078714       6
#
#    param_kernel                        params  split0_test_score  \
# 0        linear  {'C': 1, 'kernel': 'linear'}           0.889952
# 1           rbf     {'C': 1, 'kernel': 'rbf'}           0.000000
# 2          poly    {'C': 1, 'kernel': 'poly'}           0.000000
# 3        linear  {'C': 2, 'kernel': 'linear'}           0.889952
# 4           rbf     {'C': 2, 'kernel': 'rbf'}           0.000000
# 5          poly    {'C': 2, 'kernel': 'poly'}           0.000000
# 6        linear  {'C': 3, 'kernel': 'linear'}           0.889952
# 7           rbf     {'C': 3, 'kernel': 'rbf'}           0.000000
# 8          poly    {'C': 3, 'kernel': 'poly'}           0.000000
# 9        linear  {'C': 4, 'kernel': 'linear'}           0.889952
# 10          rbf     {'C': 4, 'kernel': 'rbf'}           0.000000
# 11         poly    {'C': 4, 'kernel': 'poly'}           0.000000
# 12       linear  {'C': 5, 'kernel': 'linear'}           0.889952
# 13          rbf     {'C': 5, 'kernel': 'rbf'}           0.000000
# 14         poly    {'C': 5, 'kernel': 'poly'}           0.000000
# 15       linear  {'C': 6, 'kernel': 'linear'}           0.889952
# 16          rbf     {'C': 6, 'kernel': 'rbf'}           0.000000
# 17         poly    {'C': 6, 'kernel': 'poly'}           0.000000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.861386           0.833333           0.865385
# 1            0.000000           0.000000           0.000000
# 2            0.000000           0.000000           0.000000
# 3            0.861386           0.833333           0.865385
# 4            0.000000           0.000000           0.000000
# 5            0.000000           0.000000           0.000000
# 6            0.861386           0.833333           0.865385
# 7            0.000000           0.000000           0.000000
# 8            0.000000           0.000000           0.000000
# 9            0.861386           0.833333           0.865385
# 10           0.000000           0.000000           0.000000
# 11           0.000000           0.000000           0.000000
# 12           0.861386           0.833333           0.865385
# 13           0.000000           0.000000           0.000000
# 14           0.000000           0.000000           0.000000
# 15           0.861386           0.833333           0.865385
# 16           0.000000           0.000000           0.000000
# 17           0.000000           0.000000           0.000000
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.834123         0.856836        0.021254                1
# 1            0.000000         0.000000        0.000000                7
# 2            0.000000         0.000000        0.000000                7
# 3            0.834123         0.856836        0.021254                1
# 4            0.000000         0.000000        0.000000                7
# 5            0.000000         0.000000        0.000000                7
# 6            0.834123         0.856836        0.021254                1
# 7            0.000000         0.000000        0.000000                7
# 8            0.000000         0.000000        0.000000                7
# 9            0.834123         0.856836        0.021254                1
# 10           0.000000         0.000000        0.000000                7
# 11           0.000000         0.000000        0.000000                7
# 12           0.834123         0.856836        0.021254                1
# 13           0.000000         0.000000        0.000000                7
# 14           0.000000         0.000000        0.000000                7
# 15           0.834123         0.856836        0.021254                1
# 16           0.000000         0.000000        0.000000                7
# 17           0.000000         0.000000        0.000000                7

# %%
from sklearn.model_selection import cross_validate
from sklearn.svm import SVC

cv_results = cross_validate(SVC(C=1, kernel='linear'),X,y,cv=5,scoring=['f1','precision','recall','accuracy'])
for metric in cv_results:
    print(f'{metric:10}: {np.average(cv_results[metric]):5.4f}')
# Out:
# fit_time  : 38.2240
# score_time: 8.4459
# test_f1   : 0.8568
# test_precision: 0.8523
# test_recall: 0.8619
# test_accuracy: 0.9787

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix



# rng = np.random.default_rng(2022)

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=42)

clf = SVC(kernel='linear')
clf.fit(X,y)
yhat = clf.predict(X)

m = confusion_matrix(y, yhat, labels=[0, 1])
pd.DataFrame(m, index=['true irrelevant','true relevant'], columns=['pred irrelevant', 'pred revant'])
# Out:
#                  pred irrelevant  pred revant
# true irrelevant             6424            0
# true relevant                  0          514

# %%
df_results = pd.DataFrame(results.cv_results_)
df_results.to_csv('gridsearch7.csv')

# %%
# !export_out_of_tdmstudio gridsearch3.csv
# Out:
# /bin/sh: export_out_of_tdmstudio: command not found

# %% [markdown]
# ## MultinomialNB with BOW (grid search)

# %%
from sklearn.model_selection import cross_validate
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV
X_bow = pickle.load(open('cache/X_bow.p','rb'))
y_bow = pickle.load(open('cache/y_bow.p','rb'))
parameters = {'alpha':[20,30,40,50,100]}
nb = MultinomialNB()
clf = GridSearchCV(nb, parameters,scoring='f1', cv=5,verbose=4)

results = clf.fit(X_bow,y_bow)
pd.DataFrame(results.cv_results_)

# %%
from sklearn.naive_bayes import MultinomialNB

from sklearn.model_selection import cross_validate

cv_results = cross_validate(MultinomialNB(alpha=20),X,y,cv=5,scoring=['f1','precision','recall','accuracy'])
for metric in cv_results:
    print(f'{metric:10}: {np.average(cv_results[metric]):5.4f}')
# Out:
# fit_time  : 0.4311
# score_time: 0.1133
# test_f1   : 0.7435
# test_precision: 0.7219
# test_recall: 0.7684
# test_accuracy: 0.9607

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix



# rng = np.random.default_rng(2022)

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=42)

clf = MultinomialNB(alpha=20)
clf.fit(X,y)
yhat = clf.predict(X)

m = confusion_matrix(y, yhat, labels=[0, 1])
pd.DataFrame(m, index=['true irrelevant','true relevant'], columns=['pred irrelevant', 'pred revant'])
# Out:
#                  pred irrelevant  pred revant
# true irrelevant             6196          228
# true relevant                 65          449

# %% [markdown]
# ### Split train-test confusion matrix

# %%
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.svm import SVC
# from sklearn.metrics import confusion_matrix



# # rng = np.random.default_rng(2022)

# # X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=42)

# clf = SVC(C=3, kernel='poly',degree=2)
# clf.fit(X,y)
# yhat = clf.predict(X)

# m = confusion_matrix(y, yhat, labels=[0, 1])
# pd.DataFrame(m, index=['true irrelevant','true relevant'], columns=['pred irrelevant', 'pred revant'])
# Out:
#                  pred irrelevant  pred revant
# true irrelevant            11939           51
# true relevant                108          406

# %% [markdown]
# ## Working with non-dp articles

# %%
len(all_files)
# Out:
# 2057868

# %%
import pandas as pd


import pandas as pd
all_articles_df = pd.DataFrame(
                  ['unknown']*len(all_files),
                  columns=['label']
                 )
all_articles_df['source']='GM1'
all_articles_df.iloc[len(os.listdir(GM_all_part1)):, 1] = 'GM2'

all_articles_df['id'] = [file_id.split('/')[-1][:-4] for file_id in all_files]

# df['source']='GM'
# df.iloc[:len(os.listdir(TS_dirpath)),-1]='TS'
all_articles_df
# Out:
#            label source          id
# 0        unknown    GM1  1323614655
# 1        unknown    GM1  1287437740
# 2        unknown    GM1  1289475925
# 3        unknown    GM1  1287717370
# 4        unknown    GM1  1295978754
# ...          ...    ...         ...
# 2057863  unknown    GM2  1284766080
# 2057864  unknown    GM2  1288512672
# 2057865  unknown    GM2  1313948084
# 2057866  unknown    GM2  1283055041
# 2057867  unknown    GM2  1283091638
#
# [2057868 rows x 3 columns]

# %%
dp_ids = set([file_.split('/')[-1][:-4] for file_ in dp_files])
to_keep=[]
for idx,id_ in enumerate(all_articles_df['id']):
    if not id_ in dp_ids:
        to_keep.append(idx)

all_articles_df['prediction'] = -1
all_articles_df.iloc[to_keep,:]
# Out:
#            label source          id  prediction
# 0        unknown    GM1  1323614655          -1
# 1        unknown    GM1  1287437740          -1
# 2        unknown    GM1  1289475925          -1
# 3        unknown    GM1  1287717370          -1
# 4        unknown    GM1  1295978754          -1
# ...          ...    ...         ...         ...
# 2057863  unknown    GM2  1284766080          -1
# 2057864  unknown    GM2  1288512672          -1
# 2057865  unknown    GM2  1313948084          -1
# 2057866  unknown    GM2  1283055041          -1
# 2057867  unknown    GM2  1283091638          -1
#
# [2050930 rows x 4 columns]

# %% [markdown]
# ## Compute and store predictions

# %%
from sklearn.svm import SVC
clf = SVC(kernel='linear')
clf.fit(X,y)
# Out:
# SVC(kernel='linear')

# %%
vocab = build_vocab(dp_files)
word2idx = dict([(word,idx) for idx, word in enumerate(vocab)])


def process_file(file_):        
    title, text = get_title_and_text(file_)
    x = np.zeros(shape=(len(vocab)+1,), dtype='float32')
    if not title is None and not text is None:
        tokens = tokenize(title+' '+text)
        for token in tokens:
            if token in word2idx:
                x[word2idx[token]]+=1
            else:
                x[-1]+=1
        yhat = clf.predict([x])[0]
    return yhat,title
count=0
for file_ in all_files[:1000]:
    yhat,title=process_file(file_)
    if yhat>0.5:
        count+=1
        print(title)
# Out:
# Today and Tomorrow
# New Alloy Used In Gas Regulators
# THIEVES GET $1,186
# Harry A. Weingarten
# Four Arrested In Narcotic Raids
# Boy Drowns Despite Efforts of His Dog To Drag Him Out
# Married Girl, 16, Dies From Polio; Toronto Total 67
# Gifts to Hospital From All Ontario Bring Goal Near
# Western Grocert Profits Increase
# Secret Business
# Metro to Cut Police Role in Issuing Taxi Licenses
# Rigid Restrictions Curb Swiss Power
# Doctor Sentenced To 7-Year Term For Abortion
# 1 Dies, 2 Hurt, Trucks Crash In Cornwall
# Lightning Kills Mother and Son
# Red Urges Recognition
# Hadassah Plans Rehab Centre
# 3 Notes to Soviet Aim at Showdown On Berlin Rights
# Fire Leaps Track, Mill Destroyed
# Health Walkers in Canadian Debut
# Problem of Aged Social Challenge, Dr. Phillips Says
# Old Country Soccer
# Albert E. Brewer
# BETTER
# Darts After 'Old Rag,' Rescues Toronto Boy
# Roach Will Play For Providence
# Fun with Figures
# EASTER MESSAGE
# Resort Man, War Bride Found Frozen at Lake
# The Homemaker
# Quebec Planning $25 Million Issue For N.Y. Market
# New Recordings Rushed To Beat Petrillo Ban
# Shriners' Circus Is Full of Thrills
# Photo Standalone 1 -- No Title
# Sales Increase for Woolworth's
# Healing a Lost Community
# Race at 95 MPH Is Ended by Tree; 1 Killed, 1 Injured
# Actress in Coma
# Elections Act Interference Laid To Legislature
# Thousands in U.K. Hit by Influenza; Liverpool Crippled
# Married Youth Jailed
# Engine's Whistle Too Lafe, Yule Tree Fire Kills Two
# Doctors' Wives Faint
# Smuggled Pistol to Pal, Goes to Jail With Him
# Quarter-Century Stalemate
# An Indian Interprets India to Westerners
# Pair Receive Good Wishes
# HOLD CHILD DEATH INQUEST
# Photo Standalone 14 -- No Title
# Toronto Passes Fund Objective
# Soldiers, Fliers Back Home
# PERSONAL NOTES
# The Homemaker
# Quebec Darkened As Storm Strikes
# BEPLACE VALUABLE WINDOWS
# Ti-Cats Offer Coach 1953 Job
# MOTORCYCLIST INJURED
# Boys With Matches Ignite Two Homes
# Greek Airfields Bolstered by AA, Searchlights
# i U.S. Subs Sink 25 Jap Ships
# Other 4 -- No Title
# Must Be Challenged
# Charge Two Stole, Smashed Toy Train
# Red Strikers Sabotage French Trains in Effort To Prolong Walkouts
# UN Premature On Red Quitting
# Barred From Job, Ex-Convict Jailed
# Battle Blaze For 3 Hours, Loss $300,000
# Other 1 -- No Title
# Crop Conditions Generally Poorer Than a Year Ago
# Marriage Announcement 2 -- No Title
# Do Sheep Count Sheep?
# Youths Admit Stealing Cars
# American Tourists Take Dim View Of Canadians Behind the Wheel
# Work on Pipeline Now Under Way
# North Bay Visitor Re-fuses to Leave Ringside in Marital Battle, Lands in Clink
# Oust Coach-Judge From Ball Game
# Self-Reliance, Ingenuity Characteristic of Amps
# Mosher-- Taylor
# Our Children
# DISCUSS PUPILS WORK
# Villagers Are Certain Blonde Secretary Slain
# Little Progress By Conciliator
# Tri-Beiis Win Over Bears, 62-60, As Series Opens
# A Boy's Rude Awakening at Old Toronto Morgue
# Pearkes Loses in Argument Army Entitled to Priority
# $1,500,000 Armory at Soo Is Community Centre
# Virginia Woolf In Her Diary
# Foretaste of Apple Day
# Mary J. Campbell
# Name Holden To Gillies' Job
# Our Children
# Football's First Fling
# Dolan Tells Outfitters Canada Faces Best Year For Tourist Business
# Man-Eaters Continued
# Urge Abolition Of Scarlet Fever Quarantine Plan
# School to Train Inspectors Of Sanitation
# Six Are Killed When Plane Crashes
# Welfare Official Rides in City Car To Lunch: Walton
# 'Peg Monarchs Beat Brandon Elks
# UK Pays Uruguay 62 Per Cent More For Meat Contract
# Photo Standalone 12 -- No Title
# Army Commander Killed by Mine
# Arthur Raymer
# Committee Rejects Inquiry Into Link On Site of Arcade
# Other 1 -- No Title
# Our Children
# EASTERN CORP.
# Pickets, Police Clash in U.S.; 50 Injured
# Rates at Peak: Hospital Official
# HOME DAMAGED BY FIRE
# GIVEN MEDAL AFTER 78 YEARS
# Dies of Injuries
# Alberta Records 109th Polio Death
# Guards' Strike Closes Louvre
# Social Notes
# 3 Ships Bolster U.S. Eastern Fleet
# Chemical Rain Blisters Skin And Hurts Eyes of Filipinos
# Stole Merchandiae To Pay His Bill At Dance Studio
# Commission for Traffic Control
# Rioters Quelled In Prison Fire
# Weston Minister Going to Yale
# 800 Dependents Landed by Letitia
# Norse Women Said Favored In Legal Rights
# Discovers Moose Is Poor Loser
# In Choice Role
# Couple Honored Guests On Sixtieth Anniversary
# Former DP's Making Good
# Amber Grattan Strathroy Winner
# NEW BOWLING GREENS
# Etobicoke Swimmers Win Four 1st Medals at Montreal
# At City Hall
# Encircling Manhattan
# Let Them See the Proof
# Prairies Go to Dogs, But They Bring Dough
# Marriage Announcement 2 -- No Title
# ON THE SCREEN
# Correspondence WIDOWS' RIGHTS
# Weldon F. Deverell
# 4 Aircraft Lost In Malton Blaze Uninsured: Howe
# Operator Slugged, 2 Youths Jailed
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_15295/4169989650.py in <module>
#      17 count=0
#      18 for file_ in all_files[:1000]:
# ---> 19     yhat,title=process_file(file_)
#      20     if yhat>0.5:
#      21         count+=1
#
# /tmp/ipykernel_15295/4169989650.py in process_file(file_)
#      14                 x[-1]+=1
#      15         yhat = clf.predict([x])[0]
# ---> 16     return yhat,title
#      17 count=0
#      18 for file_ in all_files[:1000]:
#
# UnboundLocalError: local variable 'yhat' referenced before assignment

# %%
import spacy
import pickle
from tqdm import tqdm


vocab = build_vocab(dp_files)
word2idx = dict([(word,idx) for idx, word in enumerate(vocab)])

nlp = spacy.load('en_core_web_lg', disable=['textcat','lemmatizer', 'parser', 'tagger','ner'])
for idx in tqdm(range(len(all_articles_df))):        
    _, source, id_, _ = all_articles_df.iloc[idx,:]
    if source=='GM1':
        file_ = GM_all_part1+id_+'.xml'
    else:
        file_ = GM_all_part2+id_+'.xml'

    title, text = get_title_and_text(file_)
    x = np.zeros(shape=(len(vocab)+1,), dtype='float32')
    if not title is None and not text is None:
        tokens = tokenize(title+' '+text)
        for token in tokens:
            if token in word2idx:
                x[word2idx[token]]+=1
            else:
                x[-1]+=1
        yhat = clf.predict([x])[0]
        all_articles_df.iloc[idx,3] = yhat
all_articles_df.to_csv('all_articles_df_bow_predictions.csv')
# Out:
#  11%|█▏        | 234398/2057868 [5:33:17<42:14:13, 11.99it/s]

# %%
print('hello')
# Out:
# hello

# %%
len(non_dp_articles_df)
# Out:
# 2045364

# %%
import spacy
import pickle
from tqdm import tqdm

if os.path.isfile('cache/X_all_bow.p'):
    info('Retrieving from disk')
    X = pickle.load(open('cache/X_all_bow.p','rb'))
else:
    info('Creating X')
    vocab = build_vocab(dp_files)
    word2idx = dict([(word,idx) for idx, word in enumerate(vocab)])
    example_no = np.sum(all_articles_df["label"]=='unknown')

    X = np.zeros(shape=(example_no, len(vocab)+1), dtype='float32')

    inst_no=0
    for idx in tqdm(list(range(len(all_articles_df)))):      
        label, source, id_ = all_articles_df.iloc[idx,:]
        if source=='GM1':
            file_ = GM_all_part1+id_+'.xml'
        else:
            file_ = GM_all_part2+id_+'.xml'

        title, text = get_title_and_text(file_)
        tokens = tokenize(title+' '+text)
        for token in tokens:
            if token in word2idx:
                X[inst_no, word2idx[token]]+=1
            else:
                X[inst_no,-1]+=1
#         X[inst_no,:300] = nlp(title).vector
#         X[inst_no,300:] = nlp(text).vector
        inst_no+=1

    pickle.dump(X, open('cache/X_all_bow.p','wb'))
# Out:
# 2022-02-22 18:27:32.597858 [ INFO  ] Creating X
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /tmp/ipykernel_15832/1049494424.py in <module>
#      12     example_no = np.sum(all_articles_df["label"]=='unknown')
#      13
# ---> 14     X = np.zeros(shape=(example_no, len(vocab)+1), dtype='float32')
#      15
#      16     inst_no=0
#
# MemoryError: Unable to allocate 76.7 GiB for an array with shape (2057868, 10001) and data type float32

# %%
X.shape
# Out:
# (0, 10001)

# %%
assert all(type(elem)==str for elem in texts+titles)

# %%
(texts+titles)[:2]
# Out:
# ["\n\n\n\xa0\n\n\n\nToday and Tomorrow\n\n\nWalter Lippmann's\n\n\nThe Voice of America\n\n\nThough money for radio broadcasts and printing is needed so that the Voice of America may be heard in foreign lands our greatest need is to have something definite clear and convincing for that voice to say There will he little opposition in Congress to an appropriation if\n\n\nit were not for the feeling that the men who conduct our propaganda have little to do with the making of our policy and that the sales department of the Government so lo speak writing about goods for which the produc tion engineers have just begun to make the first blueprints As for the customers abroad they are undoubtedly confused and suspicious partly no doubt because the rival firm misrepresents us but chiefly because we sound hot and bothered when as Great Power they expect us to be cool and definite Mr Benton's difficul ties with Congress and with the opposition abroad will diminish when his chief Secretary Marshall has had time to form and to or concrete American pro gram for the settlement of the war Program for Settlement The elements of such program have 1 believe gradually emerged from the vast ami intricate de bates and can be formulated now as the basis for further discussion They could think he stated in some such way as this 3. The division of the world into two great coalitions-- one with its centre in Moscow and the other with its centre in Washington-- is only apparent The world cannot be divided in this way The coali tions cannot be organized The nations of Kurope will resist the idea that they are the satellites of the two nog-European Great Pow ers and that their continent is the predestined theatre of Soviet- American conflict In so far as the Truman Doctrine consciously or unconsciously treats Kurope in this fashion it is an obstacle to the making of peace and is of American influence on the mill ing of peace European Guaranty Necessary 2. The revival of Kurope under the leadership of Great Britain and France now the principal European powers is necessary There can be no German settle\n\n\nment except within the frame work of European settlement The political and economic unifica tion of Germany is neither pos sible nor safe except within the framework of European Economic Union and of enough European political union lo provide the pri- guaranties of the German settlement The Russian and Ameri can guaranties of German good be will have to be secondary to the European guaranty 3. Though in the end the unity of Europe must comprehend the whole of Europe partial unity Is better than none at all The unity of Western Europe alone cannot be self-supporting and solvent It will require artificial support from the Western Hemisphere principally from the United States But if the support Is given on conditions which promote and induce unification the partial union of Western Europe will exert immense attraction upon Eastern Europe Armle Must Go Home 4. These considerations enable to state the definite terms upon which we could propose to settle the Soviet-American conflict Our object is the revival of Europe as an independent power in the world To attain this object we shall have lo provide the equivalent of Lend- Lease for term of years as the necessary working capital obtain able nowhere else for European Economic Union The Russian contribution will have to be the military evacuation simultaneously with British French and American military evacuation of the Continent The armies must go home leaving be hind them only token forces In Ger many and at sensitive and unsettled points such as Trieste and the Greek frontier Tho military ation of Europe will have to be followed by agreement that all European States may enter the European Economic Union In return for that we could afford to finance some German reparation payments and to provide some credits to the Soviets\n\n\nIn the Middle East we should propose new treaty covering the Dardanelles the borde ...
#  "\n\n\n\xa0\n\n\n\nOsgoode Hall COURT 01' AI'FKAr Peremptory lists for Monday March 24. at 11 Court Room No 1 Regina Gauthler Reglna Hughey Rcglnn Burnett Reglna Akcrs Rcclna D'Arcy Re glna Reglna Kennedy Re glna Sxvann Reglna Chrltille Regina Rifflrri Reglna on Regin Relmer Regina Lockyer Regmn Brunsdon Court Room No 2. to he spoken to Guaranty Trust ray FlecUvay Trans port Jackson re Coles Ltd Coles Premier Trust Carey Johnson re Hnrrls Estate re Glsenthwlate Con struction Co Ltd Carey Johnson John son Vlckera re Williams Estate Corbln Crowder Wilson Hill\n\n\n\n"]

# %%
if os.path.isfile('cache/X_all.p'):
    print('here')
else:
    print('there')
# Out:
# there

# %%
if os.path.isfile('cache/X_all.p'):
    print('here')
else:
    print('there')
# Out:
# there

# %%
all_files[0]
# Out:
# '/home/ec2-user/SageMaker/data/GM_all_1945_1956/1323614655.xml'

# %%
np.random.choice?
